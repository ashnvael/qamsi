# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
from sklearn.gaussian_process.kernels import RBF

from qamsi.config.trading_config import TradingConfig
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from run import Dataset, initialize

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.TOPN_US
TOP_N = 50
ESTIMATION_WINDOW = 365

ESTIMATOR = CovEstimators.GPR.value(kernel=RBF(), shrinkage_type="linear", window_size=365 * 3)

# %%
trading_config = TradingConfig(
    total_exposure=1,
    max_exposure=None,
    min_exposure=None,
    trading_lag_days=1,
)

preprocessor, runner = initialize(
    dataset=DATASET,
    trading_config=trading_config,
    topn=TOP_N,
    rebal_freq=REBAL_FREQ,
)
# Out:
# Backtest on 2000-12-29 00:00:00 to 2024-07-31 00:00:00
# Num Train Iterations: 283
# Num OOS Daily Points: 5932

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Computing Weights: 100%|██████████| 283/283 [10:15<00:00,  2.18s/it]
# StrategyStatistics:
# * final_nav = 9.171988
# * geom_avg_total_r = 0.123626
# * geom_avg_xs_r = 0.104329
# * std_xs_r = 0.149277
# * min_xs_r = -0.095921
# * max_xs_r = 0.105878
# * skew = 0.011435
# * kurtosis = 17.166400
# * max_dd = -0.276977
# * sharpe = 0.698895
# * alpha_buy_hold = 0.033741
# * tracking_error_buy_hold = 0.170298
# * ir_buy_hold = 0.198130
# * factor_loadings = {'low_risk': 0.5895728331767018, 'momentum': -0.09641403661613213, 'quality': 0.08201410482231619, 'size': 0.05743222527312025, 'value': -0.25940007836244194, 'spx': 0.6572763587048662}
# * alpha_benchmark = 0.043333
# * alpha_benchmark_pvalue = 0.065037
# * tracking_error_benchmark = 0.105757
# * ir_benchmark = 0.409742
# * ttest_pval = 0.379423
# * levene_pval = 0.000000
# * timing_ability_coef = -0.025705
# * timing_ability_pval = 0.172645

# %%
result.std_xs_r, result.sharpe
# Out:
# (0.14927720449561693, 0.6988954133695033)

# %%
runner.plot_cumulative(
    strategy_name=strategy_name,
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")
