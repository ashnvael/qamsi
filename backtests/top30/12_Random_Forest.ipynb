# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
from qamsi.config.trading_config import TradingConfig
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from run import Dataset, initialize

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.TOPN_US
TOP_N = 30
ESTIMATION_WINDOW = 365

ESTIMATOR = CovEstimators.RF.value(shrinkage_type="linear")

# %%
trading_config = TradingConfig(
    total_exposure=1,
    max_exposure=None,
    min_exposure=None,
    trading_lag_days=1,
)

preprocessor, runner = initialize(
    dataset=DATASET,
    trading_config=trading_config,
    topn=TOP_N,
    rebal_freq=REBAL_FREQ,
)
# Out:
# Backtest on 2000-12-29 00:00:00 to 2024-07-31 00:00:00
# Num Train Iterations: 283
# Num OOS Daily Points: 5932

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Computing Weights:  58%|█████▊    | 164/283 [03:07<02:15,  1.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       1 strategy = MinVariance(
#       2     cov_estimator=ESTIMATOR,
#       3     trading_config=trading_config,
#       4     window_size=ESTIMATION_WINDOW,
#       5 )
#       7 strategy_name = ESTIMATOR.__class__.__name__
# ----> 9 result = runner(
#      10     feature_processor=preprocessor,
#      11     strategy=strategy,
#      12     hedger=None,
#      13 )
#      14 result
#
# File ~/qamsi/qamsi/runner.py:213, in Runner.__call__(self, feature_processor, strategy, hedger)
#     207 def __call__(
#     208     self,
#     209     feature_processor: Preprocessor,
#     210     strategy: BaseStrategy,
#     211     hedger: BaseHedger | None = None,
#     212 ) -> StrategyStatistics:
# --> 213     return self.run(
#     214         feature_processor=feature_processor,
#     215         strategy=strategy,
#     216         hedger=hedger,
#     217     )
#
# File ~/qamsi/qamsi/runner.py:174, in Runner.run(self, feature_processor, strategy, hedger)
#     171     self._is_hedged = True
#     172     hedger.market_name = self.experiment_config.MKT_NAME
# --> 174 self.strategy_backtester(strategy, hedger)
#     176 self.strategy_total_r = self.strategy_backtester.strategy_total_r
#     177 self.strategy_excess_r = self.strategy_backtester.strategy_excess_r
#
# File ~/qamsi/qamsi/backtest/backtester.py:91, in Backtester.__call__(self, strategy, hedger)
#      88 def __call__(
#      89     self, strategy: BaseStrategy, hedger: BaseHedger | None = None
#      90 ) -> None:
# ---> 91     self.run(strategy, hedger)
#
# File ~/qamsi/qamsi/backtest/backtester.py:155, in Backtester.run(self, strategy, hedger)
#     154 def run(self, strategy: BaseStrategy, hedger: BaseHedger | None = None) -> None:
# --> 155     strategy_weights = self.calc_rolling_weights(
#     156         lambda pred_date: self.get_strategy_weights(
#     157             strategy=strategy, pred_date=pred_date
#     158         )
#     159     )
#     160     stocks_columns = ["date", *list(self.stocks_returns.simple_returns.columns)]
#     161     strategy_weights = pd.DataFrame(
#     162         strategy_weights, columns=stocks_columns
#     163     ).set_index("date")
#
# File ~/qamsi/qamsi/backtest/backtester.py:345, in Backtester.calc_rolling_weights(self, get_weights_fn)
#     342 if should_rebal:
#     343     pred_date = rebal_date - BusinessDay(n=self.trading_lag)
# --> 345     weights = get_weights_fn(pred_date)
#     347     rolling_weights.append([rebal_date, *weights.flatten().tolist()])
#     349     last_rebal_date = rebal_date
#
# File ~/qamsi/qamsi/backtest/backtester.py:156, in Backtester.run.<locals>.<lambda>(pred_date)
#     154 def run(self, strategy: BaseStrategy, hedger: BaseHedger | None = None) -> None:
#     155     strategy_weights = self.calc_rolling_weights(
# --> 156         lambda pred_date: self.get_strategy_weights(
#     157             strategy=strategy, pred_date=pred_date
#     158         )
#     159     )
#     160     stocks_columns = ["date", *list(self.stocks_returns.simple_returns.columns)]
#     161     strategy_weights = pd.DataFrame(
#     162         strategy_weights, columns=stocks_columns
#     163     ).set_index("date")
#
# File ~/qamsi/qamsi/backtest/backtester.py:302, in Backtester.get_strategy_weights(self, strategy, pred_date)
#     299 training_data, prediction_data = self.get_data(pred_date)
#     301 # Whether the strategy has a memory or retrains from scratch is handled inside the strategy obj
# --> 302 strategy.fit(training_data=training_data)
#     304 weights = strategy(prediction_data=prediction_data)
#     305 weights = np.clip(
#     306     weights,
#     307     self.trading_config.min_exposure,
#     308     self.trading_config.max_exposure,
#     309 )
#
# File ~/qamsi/qamsi/strategies/base_strategy.py:61, in BaseStrategy.fit(self, training_data)
#      50 training_data.simple_excess_returns = (
#      51     training_data.simple_excess_returns[available_stocks]
#      52     if training_data.simple_excess_returns is not None
#      53     else None
#      54 )
#      55 training_data.log_excess_returns = (
#      56     training_data.log_excess_returns[available_stocks]
#      57     if training_data.log_excess_returns is not None
#      58     else None
#      59 )
# ---> 61 self._fit(training_data=training_data)
#
# File ~/qamsi/qamsi/strategies/estimated/min_var.py:64, in MinVariance._fit(self, training_data)
#      57 training_data.log_excess_returns = (
#      58     training_data.log_excess_returns.loc[start_date:, self.available_assets]
#      59     if training_data.log_excess_returns is not None
#      60     else None
#      61 )
#      62 training_data.factors = training_data.factors.loc[start_date:]
# ---> 64 self.cov_estimator.fit(training_data)
#
# File ~/qamsi/qamsi/cov_estimators/base_cov_estimator.py:29, in BaseCovEstimator.fit(self, training_data)
#      28 def fit(self, training_data: TrainingData) -> None:
# ---> 29     self._fit(training_data=training_data)
#      30     self._fitted = True
#
# File ~/qamsi/qamsi/cov_estimators/rl/base_rl_estimator.py:111, in BaseRLCovEstimator._fit(self, training_data)
#     106 target_transformed = self.target_scaler.fit_transform(
#     107     target.values.reshape(-1, 1)
#     108 )
#     109 target = pd.Series(target_transformed.reshape(-1), index=target.index)
# --> 111 self._fit_shrinkage(features=feat, shrinkage_target=target)
#
# File ~/qamsi/qamsi/cov_estimators/rl/rf_estimator.py:47, in RandomForestCovEstimator._fit_shrinkage(self, features, shrinkage_target)
#      41 else:
#      42     self.rf = RandomForestRegressor(
#      43         n_estimators=30,
#      44         max_depth=10,
#      45         random_state=12,
#      46     )
# ---> 47     self.rf.fit(X=features, y=shrinkage_target)
#      49 self.encountered_nan = False
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/sklearn/base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/sklearn/utils/parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/sklearn/ensemble/_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree._fit(
#     189         X,
#     190         y,
#     191         sample_weight=curr_sample_weight,
#     192         check_input=False,
#     193         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     194     )
#     195 else:
#     196     tree._fit(
#     197         X,
#     198         y,
#    (...)    201         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     202     )
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)    469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
result.std_xs_r, result.sharpe
# Out:
# (0.14254919034312802, 0.9855410527139523)

# %%
runner.plot_cumulative(
    strategy_name=strategy_name,
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))

pred = ESTIMATOR.predictions

targets = runner.targets.loc[pred.index, "target"]
ma = runner.features.loc[pred.index, "target_rolling_mean"].shift(1)

plt.plot(
    targets.index,
    targets.to_numpy(),
    label="True",
    color="grey",
    alpha=0.2,
)
plt.plot(pred.index, pred.to_numpy(), label="DNK")
plt.plot(ma.index, ma.to_numpy(), label="MA")

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(targets, pred)
