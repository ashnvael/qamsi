# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
from qamsi.config.trading_config import TradingConfig
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from run import Dataset, initialize

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.TOPN_US
TOP_N = 30
ESTIMATION_WINDOW = 365

ESTIMATOR = CovEstimators.DNK.value(shrinkage_type="linear", window_size=365 * 20)

# %%
trading_config = TradingConfig(
    total_exposure=1,
    max_exposure=None,
    min_exposure=None,
    trading_lag_days=1,
)

preprocessor, runner = initialize(
    dataset=DATASET,
    trading_config=trading_config,
    topn=TOP_N,
    rebal_freq=REBAL_FREQ,
)
# Out:
# Backtest on 2000-12-29 00:00:00 to 2024-07-31 00:00:00
# Num Train Iterations: 283
# Num OOS Daily Points: 5932

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Computing Weights:   7%|▋         | 21/283 [00:09<01:54,  2.28it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 9
#       1 strategy = MinVariance(
#       2     cov_estimator=ESTIMATOR,
#       3     trading_config=trading_config,
#       4     window_size=ESTIMATION_WINDOW,
#       5 )
#       7 strategy_name = ESTIMATOR.__class__.__name__
# ----> 9 result = runner(
#      10     feature_processor=preprocessor,
#      11     strategy=strategy,
#      12     hedger=None,
#      13 )
#      14 result
#
# File ~/qamsi/qamsi/runner.py:213, in Runner.__call__(self, feature_processor, strategy, hedger)
#     207 def __call__(
#     208     self,
#     209     feature_processor: Preprocessor,
#     210     strategy: BaseStrategy,
#     211     hedger: BaseHedger | None = None,
#     212 ) -> StrategyStatistics:
# --> 213     return self.run(
#     214         feature_processor=feature_processor,
#     215         strategy=strategy,
#     216         hedger=hedger,
#     217     )
#
# File ~/qamsi/qamsi/runner.py:174, in Runner.run(self, feature_processor, strategy, hedger)
#     171     self._is_hedged = True
#     172     hedger.market_name = self.experiment_config.MKT_NAME
# --> 174 self.strategy_backtester(strategy, hedger)
#     176 self.strategy_total_r = self.strategy_backtester.strategy_total_r
#     177 self.strategy_excess_r = self.strategy_backtester.strategy_excess_r
#
# File ~/qamsi/qamsi/backtest/backtester.py:91, in Backtester.__call__(self, strategy, hedger)
#      88 def __call__(
#      89     self, strategy: BaseStrategy, hedger: BaseHedger | None = None
#      90 ) -> None:
# ---> 91     self.run(strategy, hedger)
#
# File ~/qamsi/qamsi/backtest/backtester.py:155, in Backtester.run(self, strategy, hedger)
#     154 def run(self, strategy: BaseStrategy, hedger: BaseHedger | None = None) -> None:
# --> 155     strategy_weights = self.calc_rolling_weights(
#     156         lambda pred_date: self.get_strategy_weights(
#     157             strategy=strategy, pred_date=pred_date
#     158         )
#     159     )
#     160     stocks_columns = ["date", *list(self.stocks_returns.simple_returns.columns)]
#     161     strategy_weights = pd.DataFrame(
#     162         strategy_weights, columns=stocks_columns
#     163     ).set_index("date")
#
# File ~/qamsi/qamsi/backtest/backtester.py:345, in Backtester.calc_rolling_weights(self, get_weights_fn)
#     342 if should_rebal:
#     343     pred_date = rebal_date - BusinessDay(n=self.trading_lag)
# --> 345     weights = get_weights_fn(pred_date)
#     347     rolling_weights.append([rebal_date, *weights.flatten().tolist()])
#     349     last_rebal_date = rebal_date
#
# File ~/qamsi/qamsi/backtest/backtester.py:156, in Backtester.run.<locals>.<lambda>(pred_date)
#     154 def run(self, strategy: BaseStrategy, hedger: BaseHedger | None = None) -> None:
#     155     strategy_weights = self.calc_rolling_weights(
# --> 156         lambda pred_date: self.get_strategy_weights(
#     157             strategy=strategy, pred_date=pred_date
#     158         )
#     159     )
#     160     stocks_columns = ["date", *list(self.stocks_returns.simple_returns.columns)]
#     161     strategy_weights = pd.DataFrame(
#     162         strategy_weights, columns=stocks_columns
#     163     ).set_index("date")
#
# File ~/qamsi/qamsi/backtest/backtester.py:304, in Backtester.get_strategy_weights(self, strategy, pred_date)
#     301 # Whether the strategy has a memory or retrains from scratch is handled inside the strategy obj
#     302 strategy.fit(training_data=training_data)
# --> 304 weights = strategy(prediction_data=prediction_data)
#     305 weights = np.clip(
#     306     weights,
#     307     self.trading_config.min_exposure,
#     308     self.trading_config.max_exposure,
#     309 )
#     310 return weights.to_numpy()
#
# File ~/qamsi/qamsi/strategies/base_strategy.py:81, in BaseStrategy.__call__(self, prediction_data)
#      80 def __call__(self, prediction_data: PredictionData) -> pd.DataFrame:
# ---> 81     return self.get_weights(prediction_data=prediction_data)
#
# File ~/qamsi/qamsi/strategies/base_strategy.py:70, in BaseStrategy.get_weights(self, prediction_data)
#      68 rebal_date = prediction_data.features.index[-1]
#      69 init_weights = pd.DataFrame(0.0, index=[rebal_date], columns=self.all_assets)
# ---> 70 return self._get_weights(
#      71     prediction_data=prediction_data, weights_=init_weights.copy()
#      72 )
#
# File ~/qamsi/qamsi/strategies/estimated/min_var.py:94, in MinVariance._get_weights(self, prediction_data, weights_)
#      90 def _get_weights(
#      91     self, prediction_data: PredictionData, weights_: pd.DataFrame
#      92 ) -> pd.DataFrame:
#      93     covmat = self.cov_estimator.predict(prediction_data)
# ---> 94     weights = self._optimize(covmat)
#      96     weights_.loc[:, weights.index] = weights.to_numpy()
#      98     # (!!!) Please, use only excess returns to apply this scaling correctly
#
# File ~/qamsi/qamsi/strategies/estimated/min_var.py:86, in MinVariance._optimize(self, covmat)
#      83 self.var_min = VarianceMinimizer(constraints=constraints)
#      85 self.var_min.set_objective(covmat=covmat)
# ---> 86 self.var_min.solve()
#      88 return pd.Series(self.var_min.results["weights"])
#
# File ~/qamsi/qamsi/optimization/optimization.py:194, in VarianceMinimizer.solve(self)
#     191     b = np.array([b])
#     193 P = self.objective.coefficients['P']
# --> 194 P_inv = np.linalg.inv(P)
#     196 AP_invA = A @ P_inv @ A.T
#     197 if AP_invA.shape[0] > 1:
#
# File ~/qamsi/.venv/lib/python3.12/site-packages/numpy/linalg/linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
result.std_xs_r, result.sharpe
# Out:
# (0.14405090543990845, 0.8738530060221427)

# %%
runner.plot_cumulative(
    strategy_name=strategy_name,
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))

pred = ESTIMATOR.predictions

targets = runner.targets.loc[pred.index, "target"]
ma = runner.features.loc[pred.index, "target_rolling_mean"].shift(1)

plt.plot(
    targets.index,
    targets.to_numpy(),
    label="True",
    color="grey",
    alpha=0.2,
)
plt.plot(pred.index, pred.to_numpy(), label="DNK")
plt.plot(ma.index, ma.to_numpy(), label="MA")

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(targets, pred)
# Out:
# 0.10606099014680054
