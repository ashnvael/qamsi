# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
import pandas as pd
from qamsi.config.trading_config import TradingConfig
from qamsi.runner import Runner
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from qamsi.features.preprocessor import Preprocessor
from run import Dataset
# Out:
# (CVXPY) Jun 10 04:16:41 PM: Encountered unexpected exception importing solver PROXQP:
# ImportError("dlopen(/Users/buchkovv/qamsi/.venv/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/proxsuite_pywrap.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libc++.1.dylib\n  Referenced from: <73C5C23C-530A-3E0E-A88E-7897A0C69618> /Users/buchkovv/qamsi/.venv/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/proxsuite_pywrap.cpython-312-darwin.so\n  Reason: tried: '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/opt/homebrew/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libc++.1.dylib' (no such file), '/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/opt/homebrew/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libc++.1.dylib' (no such file)")

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.SPX_US
ESTIMATION_WINDOW = 365 * 3

# %%
experiment_config = DATASET.value()

stocks = tuple(
    pd.read_csv(experiment_config.PATH_OUTPUT / experiment_config.STOCKS_LIST_FILENAME)
    .iloc[:, 0]
    .astype(str)
    .tolist(),
)
experiment_config.ASSET_UNIVERSE = stocks  # type: ignore  # noqa: PGH003

experiment_config.MIN_ROLLING_PERIODS = ESTIMATION_WINDOW + 1
experiment_config.N_LOOKBEHIND_PERIODS = None
experiment_config.REBALANCE_FREQ = REBAL_FREQ

factors = pd.read_csv(experiment_config.PATH_OUTPUT / "factors.csv")
factors["date"] = pd.to_datetime(factors["date"])
factors = factors.set_index("date")
factor_names = tuple(factors.columns.astype(str).tolist())
experiment_config.FACTORS = factor_names

prices = [stock + "_Price" for stock in list(stocks)]
preprocessor = Preprocessor(
    exclude_names=[
        *list(stocks),
        experiment_config.RF_NAME,
        *experiment_config.HEDGING_ASSETS,
        *factor_names,
        *prices,
    ],
)

trading_config = TradingConfig(
    broker_fee=0.05 / 100,
    bid_ask_spread=0.03 / 100,
    total_exposure=1,
    max_exposure=1,
    min_exposure=0,
    trading_lag_days=1,
)

runner = Runner(
    experiment_config=experiment_config,
    trading_config=trading_config,
    verbose=True,
)
# Out:
# Backtest on 2004-03-19 00:00:00 to 2023-12-29 00:00:00

# %%
ESTIMATOR = CovEstimators.QIS.value()

strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Num Train Iterations: 186
# Computing Weights:   0%|          | 0/186 [00:00<?, ?it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   1%|          | 1/186 [00:00<00:21,  8.72it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   1%|          | 2/186 [00:00<00:19,  9.34it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   2%|▏         | 4/186 [00:00<00:18,  9.64it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   3%|▎         | 5/186 [00:00<00:18,  9.69it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   3%|▎         | 6/186 [00:00<00:18,  9.50it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   4%|▍         | 7/186 [00:00<00:18,  9.58it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   4%|▍         | 8/186 [00:00<00:18,  9.69it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   5%|▍         | 9/186 [00:00<00:18,  9.48it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   5%|▌         | 10/186 [00:01<00:18,  9.37it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   6%|▌         | 11/186 [00:01<00:18,  9.47it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   6%|▋         | 12/186 [00:01<00:18,  9.50it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   8%|▊         | 14/186 [00:01<00:17,  9.63it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   8%|▊         | 15/186 [00:01<00:17,  9.54it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   9%|▊         | 16/186 [00:01<00:17,  9.55it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:   9%|▉         | 17/186 [00:01<00:17,  9.56it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  10%|▉         | 18/186 [00:01<00:17,  9.55it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  10%|█         | 19/186 [00:01<00:17,  9.61it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  11%|█         | 20/186 [00:02<00:17,  9.52it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  11%|█▏        | 21/186 [00:02<00:17,  9.52it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  12%|█▏        | 22/186 [00:02<00:17,  9.45it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  12%|█▏        | 23/186 [00:02<00:17,  9.49it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  13%|█▎        | 24/186 [00:02<00:17,  9.39it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  13%|█▎        | 25/186 [00:02<00:17,  9.42it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  14%|█▍        | 26/186 [00:02<00:16,  9.42it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  15%|█▍        | 27/186 [00:02<00:16,  9.38it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  15%|█▌        | 28/186 [00:02<00:17,  9.25it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  16%|█▌        | 29/186 [00:03<00:17,  9.18it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  16%|█▌        | 30/186 [00:03<00:17,  9.17it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  17%|█▋        | 31/186 [00:03<00:17,  9.07it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  17%|█▋        | 32/186 [00:03<00:16,  9.06it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  18%|█▊        | 33/186 [00:03<00:16,  9.13it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  18%|█▊        | 34/186 [00:03<00:16,  9.16it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  19%|█▉        | 35/186 [00:03<00:16,  9.20it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  19%|█▉        | 36/186 [00:03<00:16,  9.14it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  20%|█▉        | 37/186 [00:03<00:16,  9.08it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  20%|██        | 38/186 [00:04<00:16,  9.02it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  21%|██        | 39/186 [00:04<00:16,  8.90it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  22%|██▏       | 40/186 [00:04<00:16,  8.80it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  22%|██▏       | 41/186 [00:04<00:16,  8.75it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
# ...
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  94%|█████████▎| 174/186 [00:20<00:01,  8.27it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  94%|█████████▍| 175/186 [00:20<00:01,  8.22it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  95%|█████████▍| 176/186 [00:20<00:01,  8.10it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  95%|█████████▌| 177/186 [00:20<00:01,  8.10it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  96%|█████████▌| 178/186 [00:20<00:00,  8.12it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  96%|█████████▌| 179/186 [00:20<00:00,  8.09it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  97%|█████████▋| 180/186 [00:20<00:00,  8.06it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  97%|█████████▋| 181/186 [00:20<00:00,  7.97it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  98%|█████████▊| 182/186 [00:21<00:00,  7.88it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  98%|█████████▊| 183/186 [00:21<00:00,  7.91it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  99%|█████████▉| 184/186 [00:21<00:00,  7.93it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights:  99%|█████████▉| 185/186 [00:21<00:00,  7.95it/s]/Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: divide by zero encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: overflow encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:30: RuntimeWarning: invalid value encountered in matmul
#   sample = pd.DataFrame(np.matmul(Y.T.to_numpy(), Y.to_numpy())) / n
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: divide by zero encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: overflow encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# /Users/buchkovv/qamsi/qamsi/cov_estimators/shrinkage/qis.py:86: RuntimeWarning: invalid value encountered in matmul
#   sigmahat = pd.DataFrame(np.matmul(np.matmul(temp1, temp2), temp3))
# Computing Weights: 100%|██████████| 186/186 [00:21<00:00,  8.64it/s]
# StrategyStatistics:
# * final_nav = 5.853549
# * geom_avg_total_r = 0.152641
# * geom_avg_xs_r = 0.121747
# * std_xs_r = 0.243095
# * min_xs_r = -0.119722
# * max_xs_r = 0.108498
# * skew = -0.320426
# * kurtosis = 10.765587
# * max_dd = -0.518669
# * sharpe = 0.500819
# * alpha_buy_hold = 0.041393
# * tracking_error_buy_hold = 0.058114
# * ir_buy_hold = 0.712265
# * factor_loadings = {'low_risk': -0.23338674510963106, 'momentum': 0.042204611157232744, 'quality': -0.025708351381048208, 'size': 0.11485302971930927, 'value': 0.37941176523529657, 'spx': 0.9432251233708964}
# * alpha_benchmark = 0.038763
# * alpha_benchmark_pvalue = 0.000846
# * tracking_error_benchmark = 0.036761
# * ir_benchmark = 1.054462
# * ttest_pval = 0.335153
# * levene_pval = 0.005559
# * timing_ability_coef = -0.015576
# * timing_ability_pval = 0.137969

# %%
result.std_xs_r
# Out:
# np.float64(0.2430950370478003)

# %%
runner.plot_cumulative(
    strategy_name=strategy_name,
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")
