# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from runs import run_backtest
from qamsi.cov_estimators.cov_estimators import CovEstimators

ESTIMATOR = CovEstimators.STATIC_FACTOR_MODEL.value(
    factor_cov_estimator=CovEstimators.HISTORICAL.value(),
    residual_cov_estimator=CovEstimators.HISTORICAL.value(),
)
REBALANCE_MODE = "fully"
VERBOSE = True
PLOT_PROGRESS = False

# %%
run_result = run_backtest(
    ESTIMATOR,
    rebalance_mode=REBALANCE_MODE,
    verbose=VERBOSE,
    plot_progress=PLOT_PROGRESS,
)
# Out:
# Train data on 2004-03-23 00:00:00 to 2022-03-31 00:00:00
# Test data on 2022-04-01 00:00:00 to 2024-12-31 00:00:00
# Num Train Iterations: 4539
# Running backtest...
# 4287it [01:13, 57.95it/s]
# Running backtest...
# 4287it [00:25, 167.78it/s]

# %%
run_result.strategy.std, run_result.baseline.std
# Out:
# (np.float64(0.13452829606670783), np.float64(0.11948690826388912))

# %%
run_result.strategy
# Out:
# StrategyStatistics:
# * final_nav = 4.207094
# * final_rf = 1.624537
# * mean = 0.086321
# * std = 0.134528
# * skew = -0.774796
# * kurtosis = 8.878057
# * max_dd = -0.253237
# * sharpe = 0.430874
# * alpha_buy_hold = 0.047031
# * tracking_error_buy_hold = 0.134954
# * ir_buy_hold = 0.348498
# * factor_loadings = {'spx': 0.4985399500837586}
# * alpha_benchmark = 0.034439
# * alpha_benchmark_pvalue = 0.144138
# * tracking_error_benchmark = 0.108261
# * ir_benchmark = 0.318108
# * ttest_pval = 0.211745
# * levene_pval = 0.037320
# * timing_ability_coef = -0.262432
# * timing_ability_pval = 0.028073

# %%
run_result.baseline
# Out:
# StrategyStatistics:
# * final_nav = 4.273097
# * final_rf = 1.624537
# * mean = 0.087296
# * std = 0.119487
# * skew = -1.590499
# * kurtosis = 12.226572
# * max_dd = -0.246916
# * sharpe = 0.493273
# * alpha_buy_hold = 0.048006
# * tracking_error_buy_hold = 0.096699
# * ir_buy_hold = 0.496450
# * factor_loadings = {'spx': 0.5974964547899324}
# * alpha_benchmark = 0.031514
# * alpha_benchmark_pvalue = 0.064006
# * tracking_error_benchmark = 0.071762
# * ir_benchmark = 0.439141
# * ttest_pval = 0.206631
# * levene_pval = 0.000142
# * timing_ability_coef = -0.187799
# * timing_ability_pval = 0.017752
