# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
from qamsi.config.trading_config import TradingConfig
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from run import Dataset, initialize

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.TOPN_US
TOP_N = 500
ESTIMATION_WINDOW = 365

ESTIMATOR = CovEstimators.PRETRAINED.value(name="irl")

# %%
trading_config = TradingConfig(
    total_exposure=1,
    max_exposure=None,
    min_exposure=None,
    trading_lag_days=0,
)

preprocessor, runner = initialize(
    dataset=DATASET,
    with_causal_window=False,
    trading_config=trading_config,
    topn=TOP_N,
    rebal_freq=REBAL_FREQ,
)
# Out:
# Backtest on 2000-12-29 00:00:00 to 2024-07-31 00:00:00
# Num Train Iterations: 283
# Num OOS Daily Points: 5932

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Computing Weights: 100%|██████████| 283/283 [01:27<00:00,  3.22it/s]
# StrategyStatistics:
# * final_nav = 10.526515
# * geom_avg_total_r = 0.131796
# * geom_avg_xs_r = 0.103512
# * std_xs_r = 0.114582
# * min_xs_r = -0.091967
# * max_xs_r = 0.066689
# * skew = -0.848493
# * kurtosis = 20.042646
# * max_dd = -0.278882
# * sharpe = 0.903384
# * alpha_buy_hold = 0.054224
# * tracking_error_buy_hold = 0.168051
# * ir_buy_hold = 0.322667
# * factor_loadings = {'low_risk': 0.5123560173249204, 'momentum': -0.028415420151199182, 'quality': 0.03517509570241079, 'size': 0.11087271433254905, 'value': -0.23982773933922716, 'spx': 0.5422489514492485}
# * alpha_benchmark = 0.063061
# * alpha_benchmark_pvalue = 0.000625
# * tracking_error_benchmark = 0.076547
# * ir_benchmark = 0.823819
# * ttest_pval = 0.280595
# * levene_pval = 0.000000
# * timing_ability_coef = -0.067263
# * timing_ability_pval = 0.000002

# %%
result.std_xs_r, result.sharpe
# Out:
# (0.1145820361619085, 0.9033835461390002)

# %%
runner.plot_cumulative(
    strategy_name=strategy_name,
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))

pred = ESTIMATOR.predictions

targets = runner.targets.loc[pred.index, "target"]
ma = runner.features.loc[pred.index, "target_rolling_mean"].shift(1)

plt.plot(
    targets.index,
    targets.to_numpy(),
    label="True",
    color="grey",
    alpha=0.2,
)
plt.plot(pred.index, pred.to_numpy(), label="DNK")
plt.plot(ma.index, ma.to_numpy(), label="MA")

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(targets, pred)
# Out:
# 0.10004951131533998

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

(targets.to_numpy() - pred.to_numpy()).mean(), mean_absolute_error(targets, pred), mean_squared_error(targets, pred)
# Out:
# (0.012568231483271207, 0.10004951131533998, 0.023278733795558417)
