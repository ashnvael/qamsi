# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
from qamsi.config.trading_config import TradingConfig
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from run import Dataset, initialize

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.TOPN_US
TOP_N = 100
ESTIMATION_WINDOW = 365

ESTIMATOR = CovEstimators.PRETRAINED.value(name="irl_gail")

# %%
trading_config = TradingConfig(
    total_exposure=1,
    max_exposure=None,
    min_exposure=None,
    trading_lag_days=0,
)

preprocessor, runner = initialize(
    dataset=DATASET,
    with_causal_window=False,
    trading_config=trading_config,
    topn=TOP_N,
    rebal_freq=REBAL_FREQ,
)
# Out:
# Backtest on 2000-12-29 00:00:00 to 2024-07-31 00:00:00
# Num Train Iterations: 283
# Num OOS Daily Points: 5932

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Computing Weights: 100%|██████████| 283/283 [28:12<00:00,  5.98s/it]
# StrategyStatistics:
# * final_nav = 9.813057
# * geom_avg_total_r = 0.127626
# * geom_avg_xs_r = 0.108329
# * std_xs_r = 0.131680
# * min_xs_r = -0.096333
# * max_xs_r = 0.074612
# * skew = -0.436454
# * kurtosis = 18.784093
# * max_dd = -0.299119
# * sharpe = 0.822667
# * alpha_buy_hold = 0.037741
# * tracking_error_buy_hold = 0.156602
# * ir_buy_hold = 0.240998
# * factor_loadings = {'low_risk': 0.5413899569264959, 'momentum': -0.06355846564922248, 'quality': 0.12214036005939023, 'size': 0.12579085054493055, 'value': -0.2232691369137195, 'spx': 0.6412993324734113}
# * alpha_benchmark = 0.043721
# * alpha_benchmark_pvalue = 0.023714
# * tracking_error_benchmark = 0.082509
# * ir_benchmark = 0.529893
# * ttest_pval = 0.367791
# * levene_pval = 0.000000
# * timing_ability_coef = -0.057389
# * timing_ability_pval = 0.000170

# %%
result.std_xs_r, result.sharpe
# Out:
# (0.13168013308681364, 0.8226671679700287)

# %%
runner.plot_cumulative(
    strategy_name=strategy_name,
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))

pred = ESTIMATOR.predictions

targets = runner.targets.loc[pred.index, "target"]
ma = runner.features.loc[pred.index, "target_rolling_mean"].shift(1)

plt.plot(
    targets.index,
    targets.to_numpy(),
    label="True",
    color="grey",
    alpha=0.2,
)
plt.plot(pred.index, pred.to_numpy(), label="DNK")
plt.plot(ma.index, ma.to_numpy(), label="MA")

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(targets, pred)
# Out:
# 0.06195350965324937
