# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
from qamsi.config.trading_config import TradingConfig
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from run import Dataset, initialize

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.TOPN_US
TOP_N = 500
ESTIMATION_WINDOW = 365

ESTIMATOR = CovEstimators.PRETRAINED.value(name="irl")

# %%
trading_config = TradingConfig(
    total_exposure=1,
    max_exposure=None,
    min_exposure=None,
    trading_lag_days=2,
)

preprocessor, runner = initialize(
    dataset=DATASET,
    with_causal_window=False,
    trading_config=trading_config,
    topn=TOP_N,
    rebal_freq=REBAL_FREQ,
)
# Out:
# Backtest on 2000-12-29 00:00:00 to 2024-07-31 00:00:00
# Num Train Iterations: 283
# Num OOS Daily Points: 5932

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Computing Weights: 100%|██████████| 283/283 [01:34<00:00,  2.99it/s]
# StrategyStatistics:
# * final_nav = 8.995289
# * geom_avg_total_r = 0.122477
# * geom_avg_xs_r = 0.094193
# * std_xs_r = 0.118571
# * min_xs_r = -0.099276
# * max_xs_r = 0.067771
# * skew = -0.825092
# * kurtosis = 24.920749
# * max_dd = -0.301706
# * sharpe = 0.794399
# * alpha_buy_hold = 0.044905
# * tracking_error_buy_hold = 0.167559
# * ir_buy_hold = 0.267997
# * factor_loadings = {'low_risk': 0.5346557579485309, 'momentum': -0.023179571001045722, 'quality': 0.02855127114640443, 'size': 0.10400501739623327, 'value': -0.252121844442578, 'spx': 0.5640067973652072}
# * alpha_benchmark = 0.052813
# * alpha_benchmark_pvalue = 0.004573
# * tracking_error_benchmark = 0.078596
# * ir_benchmark = 0.671955
# * ttest_pval = 0.330637
# * levene_pval = 0.000000
# * timing_ability_coef = -0.078056
# * timing_ability_pval = 0.000000

# %%
result.std_xs_r, result.sharpe
# Out:
# (0.11857081274152778, 0.7943988130124106)

# %%
runner.plot_cumulative(
    strategy_name="AIRL",
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))

pred = ESTIMATOR.predictions

targets = runner.targets.loc[pred.index, "target"]
ma = runner.features.loc[pred.index, "target_rolling_mean"].shift(1)

plt.plot(
    targets.index,
    targets.to_numpy(),
    label="True",
    color="grey",
    alpha=0.2,
)
plt.plot(pred.index, pred.to_numpy(), label="DNK")
plt.plot(ma.index, ma.to_numpy(), label="MA")

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(targets, pred)
# Out:
# 0.10148489439769903
