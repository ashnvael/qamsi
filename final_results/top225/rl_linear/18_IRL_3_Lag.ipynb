# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
from qamsi.config.trading_config import TradingConfig
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from run import Dataset, initialize

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.TOPN_US
TOP_N = 225
ESTIMATION_WINDOW = 365

ESTIMATOR = CovEstimators.PRETRAINED.value(name="irl")

# %%
trading_config = TradingConfig(
    total_exposure=1,
    max_exposure=None,
    min_exposure=None,
    trading_lag_days=3,
)

preprocessor, runner = initialize(
    dataset=DATASET,
    with_causal_window=False,
    trading_config=trading_config,
    topn=TOP_N,
    rebal_freq=REBAL_FREQ,
)
# Out:
# Backtest on 2000-12-29 00:00:00 to 2024-07-31 00:00:00
# Num Train Iterations: 283
# Num OOS Daily Points: 5932

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Computing Weights: 100%|██████████| 283/283 [00:40<00:00,  7.01it/s]
# StrategyStatistics:
# * final_nav = 10.827954
# * geom_avg_total_r = 0.133478
# * geom_avg_xs_r = 0.105193
# * std_xs_r = 0.126643
# * min_xs_r = -0.094438
# * max_xs_r = 0.084119
# * skew = -0.316705
# * kurtosis = 22.412155
# * max_dd = -0.309540
# * sharpe = 0.830632
# * alpha_buy_hold = 0.055906
# * tracking_error_buy_hold = 0.153333
# * ir_buy_hold = 0.364609
# * factor_loadings = {'low_risk': 0.47550158172912194, 'momentum': -0.03682667863353654, 'quality': 0.067486199607374, 'size': 0.07293493121898986, 'value': -0.20359200512167386, 'spx': 0.6130954935284005}
# * alpha_benchmark = 0.059620
# * alpha_benchmark_pvalue = 0.001417
# * tracking_error_benchmark = 0.077670
# * ir_benchmark = 0.767603
# * ttest_pval = 0.268118
# * levene_pval = 0.000000
# * timing_ability_coef = -0.057828
# * timing_ability_pval = 0.000048

# %%
result.std_xs_r, result.sharpe
# Out:
# (0.1266426820898845, 0.8306321244603072)

# %%
runner.plot_cumulative(
    strategy_name="AIRL",
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 9))

pred = ESTIMATOR.predictions

targets = runner.targets.loc[pred.index, "target"]
ma = runner.features.loc[pred.index, "target_rolling_mean"].shift(1)

plt.plot(
    targets.index,
    targets.to_numpy(),
    label="True",
    color="grey",
    alpha=0.2,
)
plt.plot(pred.index, pred.to_numpy(), label="DNK")
plt.plot(ma.index, ma.to_numpy(), label="MA")

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(targets, pred)
# Out:
# 0.06923836280540738
