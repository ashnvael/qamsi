# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Minimum Variance Portfolio Backtest.

# %%
import pandas as pd
from qamsi.config.trading_config import TradingConfig
from qamsi.runner import Runner
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from qamsi.features.preprocessor import Preprocessor
from run import Dataset
# Out:
# (CVXPY) Jun 11 01:59:29 PM: Encountered unexpected exception importing solver PROXQP:
# ImportError("dlopen(/Users/buchkovv/qamsi/.venv/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/proxsuite_pywrap.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libc++.1.dylib\n  Referenced from: <73C5C23C-530A-3E0E-A88E-7897A0C69618> /Users/buchkovv/qamsi/.venv/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/proxsuite_pywrap.cpython-312-darwin.so\n  Reason: tried: '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/opt/homebrew/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libc++.1.dylib' (no such file), '/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/opt/homebrew/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libc++.1.dylib' (no such file)")

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.SPX_US
ESTIMATION_WINDOW = 365 * 3

ESTIMATOR = CovEstimators.STATIC_FACTOR_MODEL.value(
    factor_cov_estimator=CovEstimators.HISTORICAL.value(),
    residual_cov_estimator=CovEstimators.SHRINKAGE_PCA.value(k=5),
)

# %%
experiment_config = DATASET.value()

stocks = tuple(
    pd.read_csv(experiment_config.PATH_OUTPUT / experiment_config.STOCKS_LIST_FILENAME)
    .iloc[:, 0]
    .astype(str)
    .tolist(),
)
experiment_config.ASSET_UNIVERSE = stocks  # type: ignore  # noqa: PGH003

experiment_config.MIN_ROLLING_PERIODS = ESTIMATION_WINDOW + 1
experiment_config.N_LOOKBEHIND_PERIODS = None
experiment_config.REBALANCE_FREQ = REBAL_FREQ

factors = pd.read_csv(experiment_config.PATH_OUTPUT / "factors.csv")
factors["date"] = pd.to_datetime(factors["date"])
factors = factors.set_index("date")
factor_names = tuple(factors.columns.astype(str).tolist())
experiment_config.FACTORS = factor_names

prices = [stock + "_Price" for stock in list(stocks)]
preprocessor = Preprocessor(
    exclude_names=[
        *list(stocks),
        experiment_config.RF_NAME,
        *experiment_config.HEDGING_ASSETS,
        *factor_names,
        *prices,
    ],
)

trading_config = TradingConfig(
    broker_fee=0.05 / 100,
    bid_ask_spread=0.03 / 100,
    total_exposure=1,
    max_exposure=1,
    min_exposure=0,
    trading_lag_days=1,
)

runner = Runner(
    experiment_config=experiment_config,
    trading_config=trading_config,
    verbose=True,
)
# Out:
# Backtest on 2004-03-19 00:00:00 to 2023-12-29 00:00:00

# %%
strategy = MinVariance(
    cov_estimator=ESTIMATOR,
    trading_config=trading_config,
    window_size=ESTIMATION_WINDOW,
)

strategy_name = ESTIMATOR.__class__.__name__

result = runner(
    feature_processor=preprocessor,
    strategy=strategy,
    hedger=None,
)
result
# Out:
# Num Train Iterations: 186
# Computing Weights:  19%|█▉        | 35/186 [00:22<01:38,  1.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/sr/lzvmv9j54ks_jl4x99t250r00000gn/T/ipykernel_42663/2783026444.py in ?()
#       5 )
#       6
#       7 strategy_name = ESTIMATOR.__class__.__name__
#       8
# ----> 9 result = runner(
#      10     feature_processor=preprocessor,
#      11     strategy=strategy,
#      12     hedger=None,
#
# ~/qamsi/qamsi/runner.py in ?(self, feature_processor, strategy, hedger)
#     203         feature_processor: Preprocessor,
#     204         strategy: BaseStrategy,
#     205         hedger: BaseHedger | None = None,
#     206     ) -> StrategyStatistics:
# --> 207         return self.run(
#     208             feature_processor=feature_processor,
#     209             strategy=strategy,
#     210             hedger=hedger,
#
# ~/qamsi/qamsi/runner.py in ?(self, feature_processor, strategy, hedger)
#     186         else:
#     187             self._is_hedged = True
#     188             hedger.market_name = self.experiment_config.MKT_NAME
#     189
# --> 190         return self._run_backtest(
#     191             feature_processor=feature_processor,
#     192             strategy=strategy,
#     193             features=self.features,
#
# ~/qamsi/qamsi/runner.py in ?(self, feature_processor, strategy, features, returns, rf, factors, hedging_assets, hedger)
#     154             hedge_freq=hedge_freq,
#     155             verbose=self.verbose,
#     156             hedging_assets=hedging_assets_ret,
#     157         )
# --> 158         backtester(strategy, hedger)
#     159
#     160         self.strategy_backtester = backtester
#     161
#
# ~/qamsi/qamsi/backtest/backtester.py in ?(self, strategy, hedger)
#      77     def __call__(
#      78         self, strategy: BaseStrategy, hedger: BaseHedger | None = None
#      79     ) -> None:
# ---> 80         self.run(strategy, hedger)
#
# ~/qamsi/qamsi/backtest/backtester.py in ?(self, strategy, hedger)
#     135     def run(self, strategy: BaseStrategy, hedger: BaseHedger | None = None) -> None:
# --> 136         strategy_weights = self.get_strategy_weights(strategy)
#     137         self._rebal_weights = strategy_weights
#     138         stocks_total_r = self.stocks_returns.simple_returns
#     139         float_w_normalized, strategy_unhedged_total_r = self.float_weights(
#
# ~/qamsi/qamsi/backtest/backtester.py in ?(self, strategy)
#     251                     market_cap=pred_mkt_caps,
#     252                 )
#     253
#     254                 # Whether the strategy has a memory or retrains from scratch is handled inside the strategy obj
# --> 255                 strategy.fit(training_data=training_data)
#     256
#     257                 weights = strategy(prediction_data=prediction_data)
#     258                 weights = np.clip(
#
# ~/qamsi/qamsi/strategies/base_strategy.py in ?(self, training_data)
#      49             if training_data.targets is not None
#      50             else None
#      51         )
#      52
# ---> 53         self._fit(training_data=training_data)
#
# ~/qamsi/qamsi/strategies/estimated/min_var.py in ?(self, training_data)
#      60         )
#      61         training_data.features = training_data.features.loc[start_date:]
#      62         training_data.factors = training_data.factors.loc[start_date:]
#      63
# ---> 64         self.cov_estimator.fit(training_data)
#
# ~/qamsi/qamsi/cov_estimators/base_cov_estimator.py in ?(self, training_data)
#      28     def fit(self, training_data: TrainingData) -> None:
# ---> 29         self._fit(training_data=training_data)
#      30         self._fitted = True
#
# ~/qamsi/qamsi/cov_estimators/factor/factor_cov_estimator.py in ?(self, training_data)
#      45         resid_train_data.simple_excess_returns = self._residuals
#      46         resid_train_data.log_excess_returns = None
#      47
#      48         self.factor_cov_estimator.fit(factor_train_data)
# ---> 49         self.residual_cov_estimator.fit(resid_train_data)
#
# ~/qamsi/qamsi/cov_estimators/base_cov_estimator.py in ?(self, training_data)
#      28     def fit(self, training_data: TrainingData) -> None:
# ---> 29         self._fit(training_data=training_data)
#      30         self._fitted = True
#
# ~/qamsi/qamsi/cov_estimators/shrinkage/pca_cov_estimator.py in ?(self, training_data)
#      26         ret = training_data.simple_excess_returns
#      27
#      28         self._obs_cov = ret.cov()
#      29         self._fitted_vols = np.eye(ret.shape[1]) * ret.std().to_numpy()
# ---> 30         corr = ret.corr().to_numpy()
#      31
#      32         self._pca.fit(corr)
#      33
#
# ~/qamsi/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, method, min_periods, numeric_only)
#   11048         idx = cols.copy()
#   11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
# > 11052             correl = libalgos.nancorr(mat, minp=min_periods)
#   11053         elif method == "spearman":
#   11054             correl = libalgos.nancorr_spearman(mat, minp=min_periods)
#   11055         elif method == "kendall" or callable(method):
#
# KeyboardInterrupt:

# %%
result.std_xs_r, result.sharpe
# Out:
# (np.float64(0.1486096998423157), np.float64(0.43305597425229947))

# %%
runner.plot_cumulative(
    strategy_name=strategy_name,
    include_factors=True,
)

# %%
runner.plot_turnover()

# %%
runner.plot_outperformance(mkt_only=True)

# %%
runner.save(DATASET.name + strategy_name + f"_rebal{REBAL_FREQ}")
