# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from run import run_backtest
from qamsi.cov_estimators.cov_estimators import CovEstimators

ESTIMATOR = CovEstimators.HISTORICAL
VERBOSE = True
PLOT_PROGRESS = False

# %%
run_result = run_backtest(
    ESTIMATOR.value(), verbose=VERBOSE, plot_progress=PLOT_PROGRESS
)
# Out:
# Train data on 2004-03-23 00:00:00 to 2022-03-31 00:00:00
# Test data on 2022-04-01 00:00:00 to 2024-12-31 00:00:00
# Num Train Iterations: 4539
# Running backtest...
# 4287it [04:09, 17.20it/s]
# Running backtest...
# 4287it [00:05, 803.52it/s]

# %%
run_result.strategy
# Out:
# StrategyStatistics:
# * final_nav = 8.467976
# * final_rf = 2.219120
# * mean = 0.165270
# * std = 0.152832
# * skew = -1.099428
# * kurtosis = 10.586150
# * max_dd = -0.150318
# * sharpe = 0.697098
# * alpha_buy_hold = 0.094441
# * tracking_error_buy_hold = 0.169253
# * ir_buy_hold = 0.557988
# * factor_loadings = {'spx': 0.4576758271035293}
# * alpha_benchmark = 0.064297
# * alpha_benchmark_pvalue = 0.022538
# * tracking_error_benchmark = 0.101482
# * ir_benchmark = 0.633581
# * ttest_pval = 0.203357
# * levene_pval = 0.000000
# * timing_ability_coef = -0.097411
# * timing_ability_pval = 0.000010

# %%
run_result.baseline
# Out:
# StrategyStatistics:
# * final_nav = 10.695283
# * final_rf = 2.219120
# * mean = 0.184915
# * std = 0.292233
# * skew = -0.199536
# * kurtosis = 8.289460
# * max_dd = -0.272547
# * sharpe = 0.431793
# * alpha_buy_hold = 0.114087
# * tracking_error_buy_hold = 0.077231
# * ir_buy_hold = 1.477216
# * factor_loadings = {'spx': 1.1375810035724927}
# * alpha_benchmark = 0.046120
# * alpha_benchmark_pvalue = 0.023445
# * tracking_error_benchmark = 0.069183
# * ir_benchmark = 0.666640
# * ttest_pval = 0.136377
# * levene_pval = 0.000054
# * timing_ability_coef = 0.052016
# * timing_ability_pval = 0.000549
