# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from run import run_backtest
from qamsi.cov_estimators.cov_estimators import CovEstimators

ESTIMATOR = CovEstimators.STATIC_FACTOR_MODEL.value(
    factor_cov_estimator=CovEstimators.GBM_PREDICTOR.value(),
    residual_cov_estimator=CovEstimators.HISTORICAL.value(),
)
REBALANCE_MODE = "fully"
VERBOSE = True
PLOT_PROGRESS = False

# %%
run_result = run_backtest(
    ESTIMATOR,
    rebalance_mode=REBALANCE_MODE,
    verbose=VERBOSE,
    plot_progress=PLOT_PROGRESS,
)
# Out:
# Train data on 2004-03-23 00:00:00 to 2022-03-31 00:00:00
# Test data on 2022-04-01 00:00:00 to 2024-12-31 00:00:00
# Num Train Iterations: 4539
# Running backtest...
# 4287it [02:05, 34.02it/s]
# Running backtest...
# 4287it [00:24, 177.97it/s]

# %%
run_result.strategy.std, run_result.baseline.std
# Out:
# (np.float64(0.13275982191058022), np.float64(0.11948690826388916))

# %%
run_result.strategy
# Out:
# StrategyStatistics:
# * final_nav = 4.508148
# * final_rf = 1.624537
# * mean = 0.090657
# * std = 0.132760
# * skew = -0.946728
# * kurtosis = 9.354643
# * max_dd = -0.240702
# * sharpe = 0.469268
# * alpha_buy_hold = 0.051367
# * tracking_error_buy_hold = 0.131578
# * ir_buy_hold = 0.390389
# * factor_loadings = {'spx': 0.506935185912551}
# * alpha_benchmark = 0.038433
# * alpha_benchmark_pvalue = 0.101900
# * tracking_error_benchmark = 0.105089
# * ir_benchmark = 0.365714
# * ttest_pval = 0.189331
# * levene_pval = 0.022528
# * timing_ability_coef = -0.253369
# * timing_ability_pval = 0.028911

# %%
run_result.baseline
# Out:
# StrategyStatistics:
# * final_nav = 4.273097
# * final_rf = 1.624537
# * mean = 0.087296
# * std = 0.119487
# * skew = -1.590499
# * kurtosis = 12.226572
# * max_dd = -0.246916
# * sharpe = 0.493273
# * alpha_buy_hold = 0.048006
# * tracking_error_buy_hold = 0.096699
# * ir_buy_hold = 0.496450
# * factor_loadings = {'spx': 0.5974964547899326}
# * alpha_benchmark = 0.031514
# * alpha_benchmark_pvalue = 0.064006
# * tracking_error_benchmark = 0.071762
# * ir_benchmark = 0.439141
# * ttest_pval = 0.206631
# * levene_pval = 0.000142
# * timing_ability_coef = -0.187799
# * timing_ability_pval = 0.017752
