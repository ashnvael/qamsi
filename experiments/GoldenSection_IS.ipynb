# %%
from __future__ import annotations

# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from qamsi.config.trading_config import TradingConfig
from qamsi.runner import Runner
from qamsi.strategies.estimated.min_var import MinVariance
from qamsi.cov_estimators.cov_estimators import CovEstimators
from qamsi.features.preprocessor import Preprocessor
from run import Dataset
# Out:
# (CVXPY) Jun 11 08:03:18 PM: Encountered unexpected exception importing solver PROXQP:
# ImportError("dlopen(/Users/buchkovv/qamsi/.venv/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/proxsuite_pywrap.cpython-312-darwin.so, 0x0002): Library not loaded: @rpath/libc++.1.dylib\n  Referenced from: <73C5C23C-530A-3E0E-A88E-7897A0C69618> /Users/buchkovv/qamsi/.venv/lib/python3.12/site-packages/cmeel.prefix/lib/python3.12/site-packages/proxsuite/proxsuite_pywrap.cpython-312-darwin.so\n  Reason: tried: '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/runner/miniconda3/envs/proxsuite/lib/libc++.1.dylib' (no such file), '/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/var/folders/0j/bwqcs4y508s2n4ck4dhf3rpc0000gn/T/cmeel-qko5evau/whl/cmeel.prefix/lib/libc++.1.dylib' (no such file), '/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/opt/homebrew/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libc++.1.dylib' (no such file), '/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/Users/buchkovv/.pyenv/versions/3.12.5/lib/libc++.1.dylib' (no such file), '/opt/homebrew/lib/libc++.1.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/opt/homebrew/lib/libc++.1.dylib' (no such file)")

# %%
REBAL_FREQ = "ME"
DATASET = Dataset.SPX_US
ESTIMATION_WINDOW = 365 * 1

# %%
experiment_config = DATASET.value()

stocks = tuple(
    pd.read_csv(experiment_config.PATH_OUTPUT / experiment_config.STOCKS_LIST_FILENAME)
    .iloc[:, 0]
    .astype(str)
    .tolist(),
)
experiment_config.ASSET_UNIVERSE = stocks  # type: ignore  # noqa: PGH003

experiment_config.MIN_ROLLING_PERIODS = ESTIMATION_WINDOW + 1
experiment_config.N_LOOKBEHIND_PERIODS = None
experiment_config.REBALANCE_FREQ = REBAL_FREQ

factors = pd.read_csv(experiment_config.PATH_OUTPUT / "factors.csv")
factors["date"] = pd.to_datetime(factors["date"])
factors = factors.set_index("date")
factor_names = tuple(factors.columns.astype(str).tolist())
experiment_config.FACTORS = factor_names

prices = [stock + "_Price" for stock in list(stocks)]
preprocessor = Preprocessor(
    exclude_names=[
        *list(stocks),
        experiment_config.RF_NAME,
        *experiment_config.HEDGING_ASSETS,
        *factor_names,
        *prices,
    ],
)

trading_config = TradingConfig(
    broker_fee=0.05 / 100,
    bid_ask_spread=0.03 / 100,
    total_exposure=1,
    max_exposure=1,
    min_exposure=0,
    trading_lag_days=1,
)

runner = Runner(
    experiment_config=experiment_config,
    trading_config=trading_config,
    verbose=False,
)

# %%
import numpy as np

class ShrinkageGoldenSection:
    GS_CONST = (1 + np.sqrt(5)) / 2

    def __init__(
        self,
        experiement_runner: Runner,
        start: pd.Timestamp,
        end: pd.Timestamp,
        max_shrinkage: float = 1,
        max_iterations: int = 10,
        acq_beta: float = 1.96,
    ) -> None:
        self.runner = experiement_runner
        self.start = start
        self.end = end
        self.acq_beta = acq_beta
        self._domain_ra = (0, max_shrinkage)
        self.max_iterations = max_iterations

        self.previous_points = []
        self.previous_targets = []

        self.optimal_shrinkage = None

    def optimize(self, ra: float) -> float:
        estimator = CovEstimators.RISKFOLIO.value(
            alpha=ra,
            estimator_type="shrunk",
        )

        strategy = MinVariance(
            cov_estimator=estimator,
            trading_config=trading_config,
            window_size=ESTIMATION_WINDOW,
        )

        fitted_r = runner.run_one_step(
            start_date=self.start,
            end_date=self.end,
            feature_processor=preprocessor,
            strategy=strategy,
        )
        return -fitted_r.std().item()

    def solve(self) -> float:
        return self._run_search(self._domain_ra[1], self.max_iterations)

    def __call__(self):
        return self.solve()

    def _run_search(self, max_ra: float, max_iter: int) -> float:
            min_ra = 0  # Risk-aversion is always non-negative

            left_ra = min_ra + (max_ra - min_ra) / (self.GS_CONST + 1)
            right_ra = max_ra - (max_ra - min_ra) / (self.GS_CONST + 1)
            left_sr = self.optimize(left_ra)
            right_sr = self.optimize(right_ra)
            for _ in range(max_iter):
                if left_sr > right_sr:
                    max_ra = right_ra
                    right_ra = left_ra
                    right_sr = left_sr
                    left_ra = min_ra + (max_ra - min_ra) / (self.GS_CONST + 1)
                    left_sr = self.optimize(left_ra)
                else:
                    min_ra = left_ra
                    left_ra = right_ra
                    left_sr = right_sr
                    right_ra = max_ra - (max_ra - min_ra) / (self.GS_CONST + 1)
                    right_sr = self.optimize(right_ra)

            if left_sr <= right_sr:
                opt_ra = right_ra
                opt_sharpe = right_sr
            else:
                opt_ra = left_ra
                opt_sharpe = left_sr

            self.optimal_sharpe = opt_sharpe

            return opt_ra

# %%
start_date = pd.Timestamp("2016-01-01")
end_date = runner.returns.simple_returns.loc[start_date:].iloc[20:].index[0]

start_date, end_date
# Out:
# (Timestamp('2016-01-01 00:00:00'), Timestamp('2016-02-02 00:00:00'))

# %%
opt = ShrinkageGoldenSection(
    experiement_runner=runner,
    start=start_date,
    end=end_date,
)
opt()
# Out:
# np.float64(0.029416855007991537)

# %%
-opt.optimal_sharpe, -opt.optimize(0.1)
# Out:
# (0.007124307545936087, 0.007195512816994873)

# %%
import gc

available_dates = runner.returns.simple_returns.index

optimal = []
for date in available_dates[251:]:
    start_date = date
    end_date = runner.returns.simple_returns.loc[start_date:].iloc[20:].index[0]

    opt = ShrinkageGoldenSection(
        experiement_runner=runner,
        start=start_date,
        end=end_date,
    )
    opt_ra = opt()

    print(f"Date: {start_date}, Volatility: {-opt.optimal_sharpe * np.sqrt(252):.6f}, Naive Volatility: {-opt.optimize(0.1) * np.sqrt(252):.6f}, Shrinkage: {opt_ra:.2f}")

    optimal.append([start_date, opt_ra])
    gc.collect()
# Out:
# Date: 2005-03-18 00:00:00, Volatility: 0.094022, Naive Volatility: 0.096129, Shrinkage: 0.32
# Date: 2005-03-21 00:00:00, Volatility: 0.093738, Naive Volatility: 0.095455, Shrinkage: 0.25
# Date: 2005-03-22 00:00:00, Volatility: 0.096399, Naive Volatility: 0.097999, Shrinkage: 0.24
# Date: 2005-03-23 00:00:00, Volatility: 0.115121, Naive Volatility: 0.124503, Shrinkage: 0.49
# Date: 2005-03-24 00:00:00, Volatility: 0.117243, Naive Volatility: 0.126993, Shrinkage: 0.49
# Date: 2005-03-28 00:00:00, Volatility: 0.120212, Naive Volatility: 0.128558, Shrinkage: 0.48
# Date: 2005-03-29 00:00:00, Volatility: 0.121938, Naive Volatility: 0.127735, Shrinkage: 0.40
# Date: 2005-03-30 00:00:00, Volatility: 0.117597, Naive Volatility: 0.124989, Shrinkage: 0.46
# Date: 2005-03-31 00:00:00, Volatility: 0.121307, Naive Volatility: 0.131892, Shrinkage: 0.55
# Date: 2005-04-01 00:00:00, Volatility: 0.126590, Naive Volatility: 0.135888, Shrinkage: 0.63
# Date: 2005-04-04 00:00:00, Volatility: 0.127042, Naive Volatility: 0.136708, Shrinkage: 0.61
# Date: 2005-04-05 00:00:00, Volatility: 0.125437, Naive Volatility: 0.135966, Shrinkage: 0.61
# Date: 2005-04-06 00:00:00, Volatility: 0.128819, Naive Volatility: 0.135848, Shrinkage: 0.55
# Date: 2005-04-07 00:00:00, Volatility: 0.128382, Naive Volatility: 0.134508, Shrinkage: 0.51
# Date: 2005-04-08 00:00:00, Volatility: 0.126743, Naive Volatility: 0.132643, Shrinkage: 0.50
# Date: 2005-04-11 00:00:00, Volatility: 0.127023, Naive Volatility: 0.132271, Shrinkage: 0.42
# Date: 2005-04-12 00:00:00, Volatility: 0.127725, Naive Volatility: 0.134097, Shrinkage: 0.42
# Date: 2005-04-13 00:00:00, Volatility: 0.126164, Naive Volatility: 0.132609, Shrinkage: 0.45
# Date: 2005-04-14 00:00:00, Volatility: 0.124978, Naive Volatility: 0.132017, Shrinkage: 0.48
# Date: 2005-04-15 00:00:00, Volatility: 0.115035, Naive Volatility: 0.123907, Shrinkage: 0.54
# Date: 2005-04-18 00:00:00, Volatility: 0.120099, Naive Volatility: 0.127829, Shrinkage: 0.56
# Date: 2005-04-19 00:00:00, Volatility: 0.120364, Naive Volatility: 0.127322, Shrinkage: 0.56
# Date: 2005-04-20 00:00:00, Volatility: 0.114122, Naive Volatility: 0.122341, Shrinkage: 0.53
# Date: 2005-04-21 00:00:00, Volatility: 0.099785, Naive Volatility: 0.100450, Shrinkage: 0.29
# Date: 2005-04-22 00:00:00, Volatility: 0.096038, Naive Volatility: 0.096200, Shrinkage: 0.15
# Date: 2005-04-25 00:00:00, Volatility: 0.092430, Naive Volatility: 0.093154, Shrinkage: 0.25
# Date: 2005-04-26 00:00:00, Volatility: 0.089753, Naive Volatility: 0.090695, Shrinkage: 0.43
# Date: 2005-04-27 00:00:00, Volatility: 0.089141, Naive Volatility: 0.089603, Shrinkage: 0.39
# Date: 2005-04-28 00:00:00, Volatility: 0.077980, Naive Volatility: 0.078636, Shrinkage: 0.00
# Date: 2005-04-29 00:00:00, Volatility: 0.072825, Naive Volatility: 0.072825, Shrinkage: 0.10
# Date: 2005-05-02 00:00:00, Volatility: 0.074202, Naive Volatility: 0.075023, Shrinkage: 0.23
# Date: 2005-05-03 00:00:00, Volatility: 0.076924, Naive Volatility: 0.077631, Shrinkage: 0.21
# Date: 2005-05-04 00:00:00, Volatility: 0.073295, Naive Volatility: 0.075215, Shrinkage: 0.34
# Date: 2005-05-05 00:00:00, Volatility: 0.073638, Naive Volatility: 0.075284, Shrinkage: 0.38
# Date: 2005-05-06 00:00:00, Volatility: 0.072992, Naive Volatility: 0.074916, Shrinkage: 0.36
# Date: 2005-05-09 00:00:00, Volatility: 0.071022, Naive Volatility: 0.073589, Shrinkage: 0.41
# Date: 2005-05-10 00:00:00, Volatility: 0.067178, Naive Volatility: 0.070544, Shrinkage: 0.51
# Date: 2005-05-11 00:00:00, Volatility: 0.067164, Naive Volatility: 0.070658, Shrinkage: 0.50
# Date: 2005-05-12 00:00:00, Volatility: 0.062947, Naive Volatility: 0.065426, Shrinkage: 0.46
# Date: 2005-05-13 00:00:00, Volatility: 0.054641, Naive Volatility: 0.056448, Shrinkage: 0.46
# Date: 2005-05-16 00:00:00, Volatility: 0.049837, Naive Volatility: 0.054265, Shrinkage: 0.55
# Date: 2005-05-17 00:00:00, Volatility: 0.049730, Naive Volatility: 0.055163, Shrinkage: 0.58
# Date: 2005-05-18 00:00:00, Volatility: 0.045834, Naive Volatility: 0.053033, Shrinkage: 0.80
# Date: 2005-05-19 00:00:00, Volatility: 0.047498, Naive Volatility: 0.053693, Shrinkage: 0.70
# Date: 2005-05-20 00:00:00, Volatility: 0.046470, Naive Volatility: 0.052623, Shrinkage: 0.70
# Date: 2005-05-23 00:00:00, Volatility: 0.047143, Naive Volatility: 0.054143, Shrinkage: 0.70
# Date: 2005-05-24 00:00:00, Volatility: 0.047000, Naive Volatility: 0.053951, Shrinkage: 0.80
# Date: 2005-05-25 00:00:00, Volatility: 0.051209, Naive Volatility: 0.058678, Shrinkage: 0.70
# Date: 2005-05-26 00:00:00, Volatility: 0.055552, Naive Volatility: 0.061510, Shrinkage: 0.81
# Date: 2005-05-27 00:00:00, Volatility: 0.054344, Naive Volatility: 0.059467, Shrinkage: 0.71
# Date: 2005-05-31 00:00:00, Volatility: 0.061786, Naive Volatility: 0.066283, Shrinkage: 0.71
# Date: 2005-06-01 00:00:00, Volatility: 0.058700, Naive Volatility: 0.063669, Shrinkage: 0.53
# Date: 2005-06-02 00:00:00, Volatility: 0.059328, Naive Volatility: 0.063784, Shrinkage: 0.54
# Date: 2005-06-03 00:00:00, Volatility: 0.057699, Naive Volatility: 0.061386, Shrinkage: 0.51
# Date: 2005-06-06 00:00:00, Volatility: 0.058612, Naive Volatility: 0.062073, Shrinkage: 0.50
# Date: 2005-06-07 00:00:00, Volatility: 0.066214, Naive Volatility: 0.069438, Shrinkage: 0.45
# Date: 2005-06-08 00:00:00, Volatility: 0.065717, Naive Volatility: 0.068489, Shrinkage: 0.45
# Date: 2005-06-09 00:00:00, Volatility: 0.072684, Naive Volatility: 0.075014, Shrinkage: 0.40
# Date: 2005-06-10 00:00:00, Volatility: 0.073627, Naive Volatility: 0.075621, Shrinkage: 0.40
# Date: 2005-06-13 00:00:00, Volatility: 0.073347, Naive Volatility: 0.074729, Shrinkage: 0.40
# Date: 2005-06-14 00:00:00, Volatility: 0.071997, Naive Volatility: 0.073480, Shrinkage: 0.42
# Date: 2005-06-15 00:00:00, Volatility: 0.071667, Naive Volatility: 0.072948, Shrinkage: 0.41
# Date: 2005-06-16 00:00:00, Volatility: 0.070479, Naive Volatility: 0.071790, Shrinkage: 0.40
# Date: 2005-06-17 00:00:00, Volatility: 0.071857, Naive Volatility: 0.073621, Shrinkage: 0.39
# Date: 2005-06-20 00:00:00, Volatility: 0.073518, Naive Volatility: 0.075159, Shrinkage: 0.40
# Date: 2005-06-21 00:00:00, Volatility: 0.073562, Naive Volatility: 0.074891, Shrinkage: 0.40
# Date: 2005-06-22 00:00:00, Volatility: 0.075385, Naive Volatility: 0.076125, Shrinkage: 0.35
# Date: 2005-06-23 00:00:00, Volatility: 0.073475, Naive Volatility: 0.074963, Shrinkage: 0.36
# Date: 2005-06-24 00:00:00, Volatility: 0.069044, Naive Volatility: 0.070229, Shrinkage: 0.40
# Date: 2005-06-27 00:00:00, Volatility: 0.068722, Naive Volatility: 0.069691, Shrinkage: 0.35
# Date: 2005-06-28 00:00:00, Volatility: 0.062773, Naive Volatility: 0.063465, Shrinkage: 0.34
# Date: 2005-06-29 00:00:00, Volatility: 0.065680, Naive Volatility: 0.066948, Shrinkage: 0.38
# Date: 2005-06-30 00:00:00, Volatility: 0.069698, Naive Volatility: 0.071357, Shrinkage: 0.38
# Date: 2005-07-01 00:00:00, Volatility: 0.070305, Naive Volatility: 0.071544, Shrinkage: 0.37
# Date: 2005-07-05 00:00:00, Volatility: 0.072246, Naive Volatility: 0.073031, Shrinkage: 0.36
# Date: 2005-07-06 00:00:00, Volatility: 0.064263, Naive Volatility: 0.065798, Shrinkage: 0.40
# Date: 2005-07-07 00:00:00, Volatility: 0.066320, Naive Volatility: 0.067240, Shrinkage: 0.33
# Date: 2005-07-08 00:00:00, Volatility: 0.063886, Naive Volatility: 0.064252, Shrinkage: 0.22
# Date: 2005-07-11 00:00:00, Volatility: 0.063522, Naive Volatility: 0.063858, Shrinkage: 0.19
# Date: 2005-07-12 00:00:00, Volatility: 0.067901, Naive Volatility: 0.068392, Shrinkage: 0.20
# Date: 2005-07-13 00:00:00, Volatility: 0.068013, Naive Volatility: 0.068405, Shrinkage: 0.19
# Date: 2005-07-14 00:00:00, Volatility: 0.072327, Naive Volatility: 0.072678, Shrinkage: 0.19
# Date: 2005-07-15 00:00:00, Volatility: 0.072976, Naive Volatility: 0.073180, Shrinkage: 0.16
# Date: 2005-07-18 00:00:00, Volatility: 0.071142, Naive Volatility: 0.071204, Shrinkage: 0.13
# Date: 2005-07-19 00:00:00, Volatility: 0.076708, Naive Volatility: 0.077002, Shrinkage: 0.01
# Date: 2005-07-20 00:00:00, Volatility: 0.076483, Naive Volatility: 0.076941, Shrinkage: 0.00
# Date: 2005-07-21 00:00:00, Volatility: 0.074880, Naive Volatility: 0.075434, Shrinkage: 0.02
# Date: 2005-07-22 00:00:00, Volatility: 0.073073, Naive Volatility: 0.073625, Shrinkage: 0.01
# Date: 2005-07-25 00:00:00, Volatility: 0.073125, Naive Volatility: 0.074451, Shrinkage: 0.00
# Date: 2005-07-26 00:00:00, Volatility: 0.073320, Naive Volatility: 0.074722, Shrinkage: 0.01
# Date: 2005-07-27 00:00:00, Volatility: 0.073799, Naive Volatility: 0.075590, Shrinkage: 0.00
# Date: 2005-07-28 00:00:00, Volatility: 0.068377, Naive Volatility: 0.069656, Shrinkage: 0.00
# Date: 2005-07-29 00:00:00, Volatility: 0.064234, Naive Volatility: 0.066741, Shrinkage: 0.00
# Date: 2005-08-01 00:00:00, Volatility: 0.067242, Naive Volatility: 0.069254, Shrinkage: 0.00
# Date: 2005-08-02 00:00:00, Volatility: 0.065366, Naive Volatility: 0.067181, Shrinkage: 0.00
# Date: 2005-08-03 00:00:00, Volatility: 0.064606, Naive Volatility: 0.067469, Shrinkage: 0.00
# Date: 2005-08-04 00:00:00, Volatility: 0.064842, Naive Volatility: 0.067465, Shrinkage: 0.00
# Date: 2005-08-05 00:00:00, Volatility: 0.063627, Naive Volatility: 0.065062, Shrinkage: 0.00
# Date: 2005-08-08 00:00:00, Volatility: 0.070747, Naive Volatility: 0.069842, Shrinkage: 0.50
# Date: 2005-08-09 00:00:00, Volatility: 0.070291, Naive Volatility: 0.069052, Shrinkage: 0.52
# Date: 2005-08-10 00:00:00, Volatility: 0.068005, Naive Volatility: 0.070336, Shrinkage: 0.00
# Date: 2005-08-11 00:00:00, Volatility: 0.068185, Naive Volatility: 0.071083, Shrinkage: 0.00
# Date: 2005-08-12 00:00:00, Volatility: 0.067959, Naive Volatility: 0.070060, Shrinkage: 0.00
# Date: 2005-08-15 00:00:00, Volatility: 0.073111, Naive Volatility: 0.075099, Shrinkage: 0.00
# Date: 2005-08-16 00:00:00, Volatility: 0.064488, Naive Volatility: 0.066137, Shrinkage: 0.00
# Date: 2005-08-17 00:00:00, Volatility: 0.064376, Naive Volatility: 0.065902, Shrinkage: 0.00
# Date: 2005-08-18 00:00:00, Volatility: 0.065229, Naive Volatility: 0.066421, Shrinkage: 0.00
# Date: 2005-08-19 00:00:00, Volatility: 0.067103, Naive Volatility: 0.068381, Shrinkage: 0.01
# Date: 2005-08-22 00:00:00, Volatility: 0.070258, Naive Volatility: 0.072342, Shrinkage: 0.00
# Date: 2005-08-23 00:00:00, Volatility: 0.072151, Naive Volatility: 0.075005, Shrinkage: 0.00
# Date: 2005-08-24 00:00:00, Volatility: 0.071436, Naive Volatility: 0.074096, Shrinkage: 0.00
# Date: 2005-08-25 00:00:00, Volatility: 0.070818, Naive Volatility: 0.073376, Shrinkage: 0.00
# Date: 2005-08-26 00:00:00, Volatility: 0.069582, Naive Volatility: 0.072088, Shrinkage: 0.00
# Date: 2005-08-29 00:00:00, Volatility: 0.068343, Naive Volatility: 0.070707, Shrinkage: 0.00
# Date: 2005-08-30 00:00:00, Volatility: 0.070238, Naive Volatility: 0.072528, Shrinkage: 0.00
# Date: 2005-08-31 00:00:00, Volatility: 0.070396, Naive Volatility: 0.072131, Shrinkage: 0.00
# Date: 2005-09-01 00:00:00, Volatility: 0.070293, Naive Volatility: 0.072329, Shrinkage: 0.00
# Date: 2005-09-02 00:00:00, Volatility: 0.070457, Naive Volatility: 0.072614, Shrinkage: 0.01
# Date: 2005-09-06 00:00:00, Volatility: 0.065954, Naive Volatility: 0.068043, Shrinkage: 0.00
# Date: 2005-09-07 00:00:00, Volatility: 0.077009, Naive Volatility: 0.078167, Shrinkage: 0.02
# Date: 2005-09-08 00:00:00, Volatility: 0.076800, Naive Volatility: 0.077791, Shrinkage: 0.04
# Date: 2005-09-09 00:00:00, Volatility: 0.073232, Naive Volatility: 0.074129, Shrinkage: 0.03
# Date: 2005-09-12 00:00:00, Volatility: 0.074536, Naive Volatility: 0.075074, Shrinkage: 0.04
# Date: 2005-09-13 00:00:00, Volatility: 0.073243, Naive Volatility: 0.073812, Shrinkage: 0.02
# Date: 2005-09-14 00:00:00, Volatility: 0.073092, Naive Volatility: 0.073613, Shrinkage: 0.02
# Date: 2005-09-15 00:00:00, Volatility: 0.071550, Naive Volatility: 0.072127, Shrinkage: 0.04
# Date: 2005-09-16 00:00:00, Volatility: 0.070772, Naive Volatility: 0.071165, Shrinkage: 0.05
# Date: 2005-09-19 00:00:00, Volatility: 0.072663, Naive Volatility: 0.073285, Shrinkage: 0.02
# Date: 2005-09-20 00:00:00, Volatility: 0.084410, Naive Volatility: 0.089612, Shrinkage: 0.44
# Date: 2005-09-21 00:00:00, Volatility: 0.084902, Naive Volatility: 0.091749, Shrinkage: 0.47
# Date: 2005-09-22 00:00:00, Volatility: 0.092898, Naive Volatility: 0.097098, Shrinkage: 0.46
# Date: 2005-09-23 00:00:00, Volatility: 0.093720, Naive Volatility: 0.099663, Shrinkage: 0.52
# Date: 2005-09-26 00:00:00, Volatility: 0.107072, Naive Volatility: 0.112137, Shrinkage: 0.51
# Date: 2005-09-27 00:00:00, Volatility: 0.107081, Naive Volatility: 0.112614, Shrinkage: 0.49
# Date: 2005-09-28 00:00:00, Volatility: 0.105835, Naive Volatility: 0.111604, Shrinkage: 0.52
# Date: 2005-09-29 00:00:00, Volatility: 0.105470, Naive Volatility: 0.112610, Shrinkage: 0.52
# Date: 2005-09-30 00:00:00, Volatility: 0.113562, Naive Volatility: 0.118031, Shrinkage: 0.46
# Date: 2005-10-03 00:00:00, Volatility: 0.114550, Naive Volatility: 0.118291, Shrinkage: 0.38
# Date: 2005-10-04 00:00:00, Volatility: 0.115584, Naive Volatility: 0.120905, Shrinkage: 0.46
# Date: 2005-10-05 00:00:00, Volatility: 0.110020, Naive Volatility: 0.115076, Shrinkage: 0.38
# Date: 2005-10-06 00:00:00, Volatility: 0.106041, Naive Volatility: 0.112317, Shrinkage: 0.39
# Date: 2005-10-07 00:00:00, Volatility: 0.105840, Naive Volatility: 0.112677, Shrinkage: 0.41
# Date: 2005-10-10 00:00:00, Volatility: 0.105043, Naive Volatility: 0.112653, Shrinkage: 0.42
# Date: 2005-10-11 00:00:00, Volatility: 0.102000, Naive Volatility: 0.109462, Shrinkage: 0.43
# Date: 2005-10-12 00:00:00, Volatility: 0.103369, Naive Volatility: 0.110786, Shrinkage: 0.44
# Date: 2005-10-13 00:00:00, Volatility: 0.105677, Naive Volatility: 0.114677, Shrinkage: 0.52
# Date: 2005-10-14 00:00:00, Volatility: 0.104931, Naive Volatility: 0.114396, Shrinkage: 0.52
# Date: 2005-10-17 00:00:00, Volatility: 0.104532, Naive Volatility: 0.113090, Shrinkage: 0.56
# Date: 2005-10-18 00:00:00, Volatility: 0.089230, Naive Volatility: 0.089997, Shrinkage: 0.17
# Date: 2005-10-19 00:00:00, Volatility: 0.081477, Naive Volatility: 0.082996, Shrinkage: 0.00
# Date: 2005-10-20 00:00:00, Volatility: 0.074205, Naive Volatility: 0.075125, Shrinkage: 0.02
# Date: 2005-10-21 00:00:00, Volatility: 0.074097, Naive Volatility: 0.074958, Shrinkage: 0.00
# Date: 2005-10-24 00:00:00, Volatility: 0.063739, Naive Volatility: 0.063893, Shrinkage: 0.09
# Date: 2005-10-25 00:00:00, Volatility: 0.064865, Naive Volatility: 0.064914, Shrinkage: 0.12
# Date: 2005-10-26 00:00:00, Volatility: 0.059381, Naive Volatility: 0.059410, Shrinkage: 0.11
# Date: 2005-10-27 00:00:00, Volatility: 0.054639, Naive Volatility: 0.054809, Shrinkage: 0.15
# Date: 2005-10-28 00:00:00, Volatility: 0.057226, Naive Volatility: 0.057304, Shrinkage: 0.12
# Date: 2005-10-31 00:00:00, Volatility: 0.057409, Naive Volatility: 0.057599, Shrinkage: 0.15
# Date: 2005-11-01 00:00:00, Volatility: 0.061374, Naive Volatility: 0.061562, Shrinkage: 0.00
# Date: 2005-11-02 00:00:00, Volatility: 0.063715, Naive Volatility: 0.063395, Shrinkage: 0.60
# Date: 2005-11-03 00:00:00, Volatility: 0.063905, Naive Volatility: 0.065315, Shrinkage: 0.59
# Date: 2005-11-04 00:00:00, Volatility: 0.063891, Naive Volatility: 0.066879, Shrinkage: 0.59
# Date: 2005-11-07 00:00:00, Volatility: 0.063221, Naive Volatility: 0.066799, Shrinkage: 0.52
# Date: 2005-11-08 00:00:00, Volatility: 0.064465, Naive Volatility: 0.065741, Shrinkage: 0.46
# Date: 2005-11-09 00:00:00, Volatility: 0.064227, Naive Volatility: 0.066026, Shrinkage: 0.49
# Date: 2005-11-10 00:00:00, Volatility: 0.058906, Naive Volatility: 0.060702, Shrinkage: 0.61
# Date: 2005-11-11 00:00:00, Volatility: 0.058606, Naive Volatility: 0.060475, Shrinkage: 0.60
# Date: 2005-11-14 00:00:00, Volatility: 0.057432, Naive Volatility: 0.058913, Shrinkage: 0.49
# Date: 2005-11-15 00:00:00, Volatility: 0.057738, Naive Volatility: 0.058662, Shrinkage: 0.48
# Date: 2005-11-16 00:00:00, Volatility: 0.058652, Naive Volatility: 0.059425, Shrinkage: 0.49
# Date: 2005-11-17 00:00:00, Volatility: 0.051292, Naive Volatility: 0.053393, Shrinkage: 0.58
# Date: 2005-11-18 00:00:00, Volatility: 0.053584, Naive Volatility: 0.054845, Shrinkage: 0.49
# Date: 2005-11-21 00:00:00, Volatility: 0.054818, Naive Volatility: 0.057400, Shrinkage: 0.58
# Date: 2005-11-22 00:00:00, Volatility: 0.054574, Naive Volatility: 0.056468, Shrinkage: 0.48
# Date: 2005-11-23 00:00:00, Volatility: 0.054903, Naive Volatility: 0.056500, Shrinkage: 0.48
# Date: 2005-11-25 00:00:00, Volatility: 0.054742, Naive Volatility: 0.056519, Shrinkage: 0.46
# Date: 2005-11-28 00:00:00, Volatility: 0.057911, Naive Volatility: 0.059818, Shrinkage: 0.47
# Date: 2005-11-29 00:00:00, Volatility: 0.058297, Naive Volatility: 0.060637, Shrinkage: 0.54
# Date: 2005-11-30 00:00:00, Volatility: 0.055437, Naive Volatility: 0.058410, Shrinkage: 0.47
# Date: 2005-12-01 00:00:00, Volatility: 0.050179, Naive Volatility: 0.055331, Shrinkage: 0.47
# Date: 2005-12-02 00:00:00, Volatility: 0.059548, Naive Volatility: 0.062832, Shrinkage: 0.44
# Date: 2005-12-05 00:00:00, Volatility: 0.060423, Naive Volatility: 0.062060, Shrinkage: 0.40
# Date: 2005-12-06 00:00:00, Volatility: 0.060244, Naive Volatility: 0.061913, Shrinkage: 0.37
# Date: 2005-12-07 00:00:00, Volatility: 0.065151, Naive Volatility: 0.067858, Shrinkage: 0.48
# Date: 2005-12-08 00:00:00, Volatility: 0.066381, Naive Volatility: 0.069370, Shrinkage: 0.44
# Date: 2005-12-09 00:00:00, Volatility: 0.066139, Naive Volatility: 0.068738, Shrinkage: 0.47
# Date: 2005-12-12 00:00:00, Volatility: 0.065723, Naive Volatility: 0.067535, Shrinkage: 0.37
# Date: 2005-12-13 00:00:00, Volatility: 0.066006, Naive Volatility: 0.070035, Shrinkage: 0.45
# Date: 2005-12-14 00:00:00, Volatility: 0.066189, Naive Volatility: 0.069500, Shrinkage: 0.53
# Date: 2005-12-15 00:00:00, Volatility: 0.066031, Naive Volatility: 0.069757, Shrinkage: 0.47
# Date: 2005-12-16 00:00:00, Volatility: 0.065974, Naive Volatility: 0.069017, Shrinkage: 0.47
# Date: 2005-12-19 00:00:00, Volatility: 0.065001, Naive Volatility: 0.069452, Shrinkage: 0.47
# Date: 2005-12-20 00:00:00, Volatility: 0.079257, Naive Volatility: 0.082929, Shrinkage: 0.48
# Date: 2005-12-21 00:00:00, Volatility: 0.079158, Naive Volatility: 0.082203, Shrinkage: 0.46
# Date: 2005-12-22 00:00:00, Volatility: 0.079664, Naive Volatility: 0.082493, Shrinkage: 0.45
# Date: 2005-12-23 00:00:00, Volatility: 0.080554, Naive Volatility: 0.084397, Shrinkage: 0.48
# Date: 2005-12-27 00:00:00, Volatility: 0.077840, Naive Volatility: 0.081308, Shrinkage: 0.54
# Date: 2005-12-28 00:00:00, Volatility: 0.078978, Naive Volatility: 0.081523, Shrinkage: 0.46
# Date: 2005-12-29 00:00:00, Volatility: 0.078494, Naive Volatility: 0.080174, Shrinkage: 0.51
# Date: 2005-12-30 00:00:00, Volatility: 0.076636, Naive Volatility: 0.078697, Shrinkage: 0.51
# Date: 2006-01-03 00:00:00, Volatility: 0.070760, Naive Volatility: 0.073284, Shrinkage: 0.49
# Date: 2006-01-04 00:00:00, Volatility: 0.072285, Naive Volatility: 0.073584, Shrinkage: 0.48
# Date: 2006-01-05 00:00:00, Volatility: 0.073407, Naive Volatility: 0.075702, Shrinkage: 0.53
# Date: 2006-01-06 00:00:00, Volatility: 0.066202, Naive Volatility: 0.067503, Shrinkage: 0.47
# Date: 2006-01-09 00:00:00, Volatility: 0.065312, Naive Volatility: 0.066552, Shrinkage: 0.44
# Date: 2006-01-10 00:00:00, Volatility: 0.071382, Naive Volatility: 0.073061, Shrinkage: 0.44
# Date: 2006-01-11 00:00:00, Volatility: 0.071375, Naive Volatility: 0.072960, Shrinkage: 0.37
# Date: 2006-01-12 00:00:00, Volatility: 0.070946, Naive Volatility: 0.072052, Shrinkage: 0.35
# Date: 2006-01-13 00:00:00, Volatility: 0.070563, Naive Volatility: 0.072025, Shrinkage: 0.36
# Date: 2006-01-17 00:00:00, Volatility: 0.076563, Naive Volatility: 0.079728, Shrinkage: 0.57
# Date: 2006-01-18 00:00:00, Volatility: 0.077804, Naive Volatility: 0.081383, Shrinkage: 0.64
# Date: 2006-01-19 00:00:00, Volatility: 0.082012, Naive Volatility: 0.087347, Shrinkage: 0.67
# Date: 2006-01-20 00:00:00, Volatility: 0.065597, Naive Volatility: 0.072578, Shrinkage: 0.72
# Date: 2006-01-23 00:00:00, Volatility: 0.067573, Naive Volatility: 0.073072, Shrinkage: 0.70
# Date: 2006-01-24 00:00:00, Volatility: 0.068204, Naive Volatility: 0.071705, Shrinkage: 0.58
# Date: 2006-01-25 00:00:00, Volatility: 0.065692, Naive Volatility: 0.068630, Shrinkage: 0.42
# Date: 2006-01-26 00:00:00, Volatility: 0.065025, Naive Volatility: 0.068908, Shrinkage: 0.47
# Date: 2006-01-27 00:00:00, Volatility: 0.064090, Naive Volatility: 0.068595, Shrinkage: 0.62
# Date: 2006-01-30 00:00:00, Volatility: 0.077904, Naive Volatility: 0.079265, Shrinkage: 0.33
# Date: 2006-01-31 00:00:00, Volatility: 0.076914, Naive Volatility: 0.077714, Shrinkage: 0.23
# Date: 2006-02-01 00:00:00, Volatility: 0.076752, Naive Volatility: 0.077266, Shrinkage: 0.20
# Date: 2006-02-02 00:00:00, Volatility: 0.078633, Naive Volatility: 0.080040, Shrinkage: 0.73
# Date: 2006-02-03 00:00:00, Volatility: 0.079690, Naive Volatility: 0.080357, Shrinkage: 0.73
# Date: 2006-02-06 00:00:00, Volatility: 0.080185, Naive Volatility: 0.080362, Shrinkage: 0.75
# Date: 2006-02-07 00:00:00, Volatility: 0.079210, Naive Volatility: 0.080145, Shrinkage: 0.76
# Date: 2006-02-08 00:00:00, Volatility: 0.074968, Naive Volatility: 0.075250, Shrinkage: 0.04
# Date: 2006-02-09 00:00:00, Volatility: 0.078964, Naive Volatility: 0.077962, Shrinkage: 0.72
# Date: 2006-02-10 00:00:00, Volatility: 0.078983, Naive Volatility: 0.077860, Shrinkage: 0.74
# Date: 2006-02-13 00:00:00, Volatility: 0.076163, Naive Volatility: 0.077527, Shrinkage: 0.00
# Date: 2006-02-14 00:00:00, Volatility: 0.071697, Naive Volatility: 0.073116, Shrinkage: 0.00
# Date: 2006-02-15 00:00:00, Volatility: 0.071160, Naive Volatility: 0.072636, Shrinkage: 0.00
# Date: 2006-02-16 00:00:00, Volatility: 0.065972, Naive Volatility: 0.068161, Shrinkage: 0.00
# Date: 2006-02-17 00:00:00, Volatility: 0.067798, Naive Volatility: 0.069396, Shrinkage: 0.02
# Date: 2006-02-21 00:00:00, Volatility: 0.069182, Naive Volatility: 0.070343, Shrinkage: 0.02
# Date: 2006-02-22 00:00:00, Volatility: 0.073435, Naive Volatility: 0.073647, Shrinkage: 0.80
# Date: 2006-02-23 00:00:00, Volatility: 0.074092, Naive Volatility: 0.074114, Shrinkage: 0.80
# Date: 2006-02-24 00:00:00, Volatility: 0.068614, Naive Volatility: 0.071193, Shrinkage: 0.00
# Date: 2006-02-27 00:00:00, Volatility: 0.073015, Naive Volatility: 0.073630, Shrinkage: 0.84
# Date: 2006-02-28 00:00:00, Volatility: 0.062787, Naive Volatility: 0.066432, Shrinkage: 0.77
# Date: 2006-03-01 00:00:00, Volatility: 0.064024, Naive Volatility: 0.068312, Shrinkage: 0.77
# Date: 2006-03-02 00:00:00, Volatility: 0.066214, Naive Volatility: 0.071775, Shrinkage: 0.82
# Date: 2006-03-03 00:00:00, Volatility: 0.066760, Naive Volatility: 0.072324, Shrinkage: 0.77
# Date: 2006-03-06 00:00:00, Volatility: 0.064555, Naive Volatility: 0.073169, Shrinkage: 0.84
# Date: 2006-03-07 00:00:00, Volatility: 0.065018, Naive Volatility: 0.073301, Shrinkage: 0.83
# Date: 2006-03-08 00:00:00, Volatility: 0.063120, Naive Volatility: 0.070748, Shrinkage: 0.74
# Date: 2006-03-09 00:00:00, Volatility: 0.063943, Naive Volatility: 0.070864, Shrinkage: 0.74
# Date: 2006-03-10 00:00:00, Volatility: 0.068289, Naive Volatility: 0.073830, Shrinkage: 0.73
# Date: 2006-03-13 00:00:00, Volatility: 0.068782, Naive Volatility: 0.074157, Shrinkage: 0.76
# Date: 2006-03-14 00:00:00, Volatility: 0.069666, Naive Volatility: 0.076980, Shrinkage: 0.89
# Date: 2006-03-15 00:00:00, Volatility: 0.068835, Naive Volatility: 0.077554, Shrinkage: 0.89
# Date: 2006-03-16 00:00:00, Volatility: 0.067211, Naive Volatility: 0.076195, Shrinkage: 0.89
# Date: 2006-03-17 00:00:00, Volatility: 0.066957, Naive Volatility: 0.074982, Shrinkage: 0.89
# Date: 2006-03-20 00:00:00, Volatility: 0.074036, Naive Volatility: 0.078758, Shrinkage: 0.51
# Date: 2006-03-21 00:00:00, Volatility: 0.074670, Naive Volatility: 0.079716, Shrinkage: 0.62
# Date: 2006-03-22 00:00:00, Volatility: 0.071574, Naive Volatility: 0.075961, Shrinkage: 0.50
# Date: 2006-03-23 00:00:00, Volatility: 0.070569, Naive Volatility: 0.075272, Shrinkage: 0.52
# Date: 2006-03-24 00:00:00, Volatility: 0.069424, Naive Volatility: 0.072879, Shrinkage: 0.44
# Date: 2006-03-27 00:00:00, Volatility: 0.067046, Naive Volatility: 0.069799, Shrinkage: 0.43
# Date: 2006-03-28 00:00:00, Volatility: 0.064305, Naive Volatility: 0.066225, Shrinkage: 0.32
# Date: 2006-03-29 00:00:00, Volatility: 0.062449, Naive Volatility: 0.064081, Shrinkage: 0.34
# Date: 2006-03-30 00:00:00, Volatility: 0.060311, Naive Volatility: 0.062542, Shrinkage: 0.35
# Date: 2006-03-31 00:00:00, Volatility: 0.059207, Naive Volatility: 0.061270, Shrinkage: 0.33
# Date: 2006-04-03 00:00:00, Volatility: 0.057691, Naive Volatility: 0.059246, Shrinkage: 0.27
# Date: 2006-04-04 00:00:00, Volatility: 0.059440, Naive Volatility: 0.060516, Shrinkage: 0.25
# Date: 2006-04-05 00:00:00, Volatility: 0.059878, Naive Volatility: 0.060942, Shrinkage: 0.24
# Date: 2006-04-06 00:00:00, Volatility: 0.064474, Naive Volatility: 0.065353, Shrinkage: 0.23
# Date: 2006-04-07 00:00:00, Volatility: 0.057358, Naive Volatility: 0.058404, Shrinkage: 0.26
# Date: 2006-04-10 00:00:00, Volatility: 0.056929, Naive Volatility: 0.057534, Shrinkage: 0.25
# Date: 2006-04-11 00:00:00, Volatility: 0.047998, Naive Volatility: 0.048611, Shrinkage: 0.27
# Date: 2006-04-12 00:00:00, Volatility: 0.056605, Naive Volatility: 0.057801, Shrinkage: 0.00
# Date: 2006-04-13 00:00:00, Volatility: 0.058145, Naive Volatility: 0.060133, Shrinkage: 0.00
# Date: 2006-04-17 00:00:00, Volatility: 0.061485, Naive Volatility: 0.063127, Shrinkage: 0.00
# Date: 2006-04-18 00:00:00, Volatility: 0.058320, Naive Volatility: 0.060033, Shrinkage: 0.00
# Date: 2006-04-19 00:00:00, Volatility: 0.067808, Naive Volatility: 0.069556, Shrinkage: 0.00
# Date: 2006-04-20 00:00:00, Volatility: 0.062186, Naive Volatility: 0.063487, Shrinkage: 0.00
# Date: 2006-04-21 00:00:00, Volatility: 0.063885, Naive Volatility: 0.065671, Shrinkage: 0.00
# Date: 2006-04-24 00:00:00, Volatility: 0.062254, Naive Volatility: 0.064380, Shrinkage: 0.00
# Date: 2006-04-25 00:00:00, Volatility: 0.063287, Naive Volatility: 0.065454, Shrinkage: 0.00
# Date: 2006-04-26 00:00:00, Volatility: 0.065663, Naive Volatility: 0.067200, Shrinkage: 0.00
# Date: 2006-04-27 00:00:00, Volatility: 0.072974, Naive Volatility: 0.074021, Shrinkage: 0.00
# Date: 2006-04-28 00:00:00, Volatility: 0.072530, Naive Volatility: 0.074106, Shrinkage: 0.00
# Date: 2006-05-01 00:00:00, Volatility: 0.075460, Naive Volatility: 0.077829, Shrinkage: 0.00
# Date: 2006-05-02 00:00:00, Volatility: 0.079761, Naive Volatility: 0.081010, Shrinkage: 0.00
# Date: 2006-05-03 00:00:00, Volatility: 0.085389, Naive Volatility: 0.085907, Shrinkage: 0.00
# Date: 2006-05-04 00:00:00, Volatility: 0.084710, Naive Volatility: 0.085260, Shrinkage: 0.00
# Date: 2006-05-05 00:00:00, Volatility: 0.090881, Naive Volatility: 0.091062, Shrinkage: 0.05
# Date: 2006-05-08 00:00:00, Volatility: 0.089673, Naive Volatility: 0.089784, Shrinkage: 0.05
# Date: 2006-05-09 00:00:00, Volatility: 0.089864, Naive Volatility: 0.089985, Shrinkage: 0.17
# Date: 2006-05-10 00:00:00, Volatility: 0.089882, Naive Volatility: 0.090008, Shrinkage: 0.16
# Date: 2006-05-11 00:00:00, Volatility: 0.085268, Naive Volatility: 0.085297, Shrinkage: 0.07
# Date: 2006-05-12 00:00:00, Volatility: 0.087942, Naive Volatility: 0.088413, Shrinkage: 0.22
# Date: 2006-05-15 00:00:00, Volatility: 0.088042, Naive Volatility: 0.089586, Shrinkage: 0.23
# Date: 2006-05-16 00:00:00, Volatility: 0.088630, Naive Volatility: 0.089563, Shrinkage: 0.20
# Date: 2006-05-17 00:00:00, Volatility: 0.093922, Naive Volatility: 0.094301, Shrinkage: 0.16
# Date: 2006-05-18 00:00:00, Volatility: 0.093216, Naive Volatility: 0.093488, Shrinkage: 0.17
# Date: 2006-05-19 00:00:00, Volatility: 0.095730, Naive Volatility: 0.096501, Shrinkage: 0.22
# Date: 2006-05-22 00:00:00, Volatility: 0.096328, Naive Volatility: 0.096712, Shrinkage: 0.19
# Date: 2006-05-23 00:00:00, Volatility: 0.097841, Naive Volatility: 0.097974, Shrinkage: 0.19
# Date: 2006-05-24 00:00:00, Volatility: 0.097234, Naive Volatility: 0.097423, Shrinkage: 0.00
# Date: 2006-05-25 00:00:00, Volatility: 0.093457, Naive Volatility: 0.093466, Shrinkage: 0.08
# Date: 2006-05-26 00:00:00, Volatility: 0.093653, Naive Volatility: 0.093795, Shrinkage: 0.15
# Date: 2006-05-30 00:00:00, Volatility: 0.092759, Naive Volatility: 0.093519, Shrinkage: 0.21
# Date: 2006-05-31 00:00:00, Volatility: 0.087360, Naive Volatility: 0.087728, Shrinkage: 0.15
# Date: 2006-06-01 00:00:00, Volatility: 0.088193, Naive Volatility: 0.088268, Shrinkage: 0.07
# Date: 2006-06-02 00:00:00, Volatility: 0.087682, Naive Volatility: 0.088502, Shrinkage: 0.03
# Date: 2006-06-05 00:00:00, Volatility: 0.082111, Naive Volatility: 0.082978, Shrinkage: 0.05
# Date: 2006-06-06 00:00:00, Volatility: 0.080770, Naive Volatility: 0.082683, Shrinkage: 0.00
# Date: 2006-06-07 00:00:00, Volatility: 0.082021, Naive Volatility: 0.083779, Shrinkage: 0.00
# Date: 2006-06-08 00:00:00, Volatility: 0.082514, Naive Volatility: 0.084009, Shrinkage: 0.01
# Date: 2006-06-09 00:00:00, Volatility: 0.082805, Naive Volatility: 0.084074, Shrinkage: 0.01
# Date: 2006-06-12 00:00:00, Volatility: 0.079681, Naive Volatility: 0.080615, Shrinkage: 0.01
# Date: 2006-06-13 00:00:00, Volatility: 0.076667, Naive Volatility: 0.077501, Shrinkage: 0.00
# Date: 2006-06-14 00:00:00, Volatility: 0.081532, Naive Volatility: 0.084118, Shrinkage: 0.00
# Date: 2006-06-15 00:00:00, Volatility: 0.076761, Naive Volatility: 0.079017, Shrinkage: 0.00
# Date: 2006-06-16 00:00:00, Volatility: 0.076920, Naive Volatility: 0.079476, Shrinkage: 0.00
# Date: 2006-06-19 00:00:00, Volatility: 0.074322, Naive Volatility: 0.076647, Shrinkage: 0.00
# Date: 2006-06-20 00:00:00, Volatility: 0.078108, Naive Volatility: 0.081510, Shrinkage: 0.00
# Date: 2006-06-21 00:00:00, Volatility: 0.076738, Naive Volatility: 0.080107, Shrinkage: 0.00
# Date: 2006-06-22 00:00:00, Volatility: 0.076994, Naive Volatility: 0.080578, Shrinkage: 0.00
# Date: 2006-06-23 00:00:00, Volatility: 0.079130, Naive Volatility: 0.082962, Shrinkage: 0.00
# Date: 2006-06-26 00:00:00, Volatility: 0.081689, Naive Volatility: 0.085563, Shrinkage: 0.00
# Date: 2006-06-27 00:00:00, Volatility: 0.078577, Naive Volatility: 0.082470, Shrinkage: 0.00
# Date: 2006-06-28 00:00:00, Volatility: 0.083001, Naive Volatility: 0.086240, Shrinkage: 0.00
# Date: 2006-06-29 00:00:00, Volatility: 0.083872, Naive Volatility: 0.085621, Shrinkage: 0.00
# Date: 2006-06-30 00:00:00, Volatility: 0.085341, Naive Volatility: 0.087555, Shrinkage: 0.00
# Date: 2006-07-03 00:00:00, Volatility: 0.088696, Naive Volatility: 0.088740, Shrinkage: 0.13
# Date: 2006-07-05 00:00:00, Volatility: 0.086411, Naive Volatility: 0.088697, Shrinkage: 0.00
# Date: 2006-07-06 00:00:00, Volatility: 0.092555, Naive Volatility: 0.093494, Shrinkage: 0.28
# Date: 2006-07-07 00:00:00, Volatility: 0.092713, Naive Volatility: 0.093915, Shrinkage: 0.32
# Date: 2006-07-10 00:00:00, Volatility: 0.091578, Naive Volatility: 0.091681, Shrinkage: 0.14
# Date: 2006-07-11 00:00:00, Volatility: 0.090754, Naive Volatility: 0.091770, Shrinkage: 0.25
# Date: 2006-07-12 00:00:00, Volatility: 0.089505, Naive Volatility: 0.090361, Shrinkage: 0.24
# Date: 2006-07-13 00:00:00, Volatility: 0.085706, Naive Volatility: 0.087803, Shrinkage: 0.27
# Date: 2006-07-14 00:00:00, Volatility: 0.082879, Naive Volatility: 0.084991, Shrinkage: 0.30
# Date: 2006-07-17 00:00:00, Volatility: 0.083297, Naive Volatility: 0.085303, Shrinkage: 0.32
# Date: 2006-07-18 00:00:00, Volatility: 0.085708, Naive Volatility: 0.087292, Shrinkage: 0.27
# Date: 2006-07-19 00:00:00, Volatility: 0.082929, Naive Volatility: 0.084477, Shrinkage: 0.63
# Date: 2006-07-20 00:00:00, Volatility: 0.081174, Naive Volatility: 0.084663, Shrinkage: 0.67
# Date: 2006-07-21 00:00:00, Volatility: 0.078909, Naive Volatility: 0.083298, Shrinkage: 0.66
# Date: 2006-07-24 00:00:00, Volatility: 0.072672, Naive Volatility: 0.079727, Shrinkage: 0.68
# Date: 2006-07-25 00:00:00, Volatility: 0.070377, Naive Volatility: 0.076374, Shrinkage: 0.69
# Date: 2006-07-26 00:00:00, Volatility: 0.072028, Naive Volatility: 0.075143, Shrinkage: 0.40
# Date: 2006-07-27 00:00:00, Volatility: 0.067945, Naive Volatility: 0.069430, Shrinkage: 0.33
# Date: 2006-07-28 00:00:00, Volatility: 0.060479, Naive Volatility: 0.060971, Shrinkage: 0.20
# Date: 2006-07-31 00:00:00, Volatility: 0.062708, Naive Volatility: 0.063397, Shrinkage: 0.21
# Date: 2006-08-01 00:00:00, Volatility: 0.060619, Naive Volatility: 0.060930, Shrinkage: 0.21
# Date: 2006-08-02 00:00:00, Volatility: 0.057805, Naive Volatility: 0.059014, Shrinkage: 0.27
# Date: 2006-08-03 00:00:00, Volatility: 0.052132, Naive Volatility: 0.052346, Shrinkage: 0.16
# Date: 2006-08-04 00:00:00, Volatility: 0.053524, Naive Volatility: 0.053817, Shrinkage: 0.15
# Date: 2006-08-07 00:00:00, Volatility: 0.051010, Naive Volatility: 0.051076, Shrinkage: 0.16
# Date: 2006-08-08 00:00:00, Volatility: 0.052040, Naive Volatility: 0.052171, Shrinkage: 0.16
# Date: 2006-08-09 00:00:00, Volatility: 0.056117, Naive Volatility: 0.056200, Shrinkage: 0.15
# Date: 2006-08-10 00:00:00, Volatility: 0.055877, Naive Volatility: 0.057123, Shrinkage: 0.37
# Date: 2006-08-11 00:00:00, Volatility: 0.054408, Naive Volatility: 0.055511, Shrinkage: 0.38
# Date: 2006-08-14 00:00:00, Volatility: 0.053634, Naive Volatility: 0.054159, Shrinkage: 0.31
# Date: 2006-08-15 00:00:00, Volatility: 0.050438, Naive Volatility: 0.050728, Shrinkage: 0.19
# Date: 2006-08-16 00:00:00, Volatility: 0.049027, Naive Volatility: 0.050510, Shrinkage: 0.34
# Date: 2006-08-17 00:00:00, Volatility: 0.048031, Naive Volatility: 0.049258, Shrinkage: 0.26
# Date: 2006-08-18 00:00:00, Volatility: 0.050469, Naive Volatility: 0.051675, Shrinkage: 0.27
# Date: 2006-08-21 00:00:00, Volatility: 0.050742, Naive Volatility: 0.052190, Shrinkage: 0.27
# Date: 2006-08-22 00:00:00, Volatility: 0.052941, Naive Volatility: 0.054158, Shrinkage: 0.26
# Date: 2006-08-23 00:00:00, Volatility: 0.052757, Naive Volatility: 0.054212, Shrinkage: 0.26
# Date: 2006-08-24 00:00:00, Volatility: 0.052192, Naive Volatility: 0.053633, Shrinkage: 0.25
# Date: 2006-08-25 00:00:00, Volatility: 0.056228, Naive Volatility: 0.057431, Shrinkage: 0.26
# Date: 2006-08-28 00:00:00, Volatility: 0.055797, Naive Volatility: 0.056966, Shrinkage: 0.33
# Date: 2006-08-29 00:00:00, Volatility: 0.053615, Naive Volatility: 0.054116, Shrinkage: 0.23
# Date: 2006-08-30 00:00:00, Volatility: 0.052907, Naive Volatility: 0.052987, Shrinkage: 0.19
# Date: 2006-08-31 00:00:00, Volatility: 0.053461, Naive Volatility: 0.053687, Shrinkage: 0.22
# Date: 2006-09-01 00:00:00, Volatility: 0.054282, Naive Volatility: 0.054812, Shrinkage: 0.24
# Date: 2006-09-05 00:00:00, Volatility: 0.054096, Naive Volatility: 0.054120, Shrinkage: 0.23
# Date: 2006-09-06 00:00:00, Volatility: 0.060462, Naive Volatility: 0.060501, Shrinkage: 0.05
# Date: 2006-09-07 00:00:00, Volatility: 0.056443, Naive Volatility: 0.056586, Shrinkage: 0.35
# Date: 2006-09-08 00:00:00, Volatility: 0.052963, Naive Volatility: 0.054099, Shrinkage: 0.00
# Date: 2006-09-11 00:00:00, Volatility: 0.054153, Naive Volatility: 0.054522, Shrinkage: 0.02
# Date: 2006-09-12 00:00:00, Volatility: 0.051742, Naive Volatility: 0.052278, Shrinkage: 0.02
# Date: 2006-09-13 00:00:00, Volatility: 0.051581, Naive Volatility: 0.052267, Shrinkage: 0.01
# Date: 2006-09-14 00:00:00, Volatility: 0.051163, Naive Volatility: 0.052321, Shrinkage: 0.01
# Date: 2006-09-15 00:00:00, Volatility: 0.050675, Naive Volatility: 0.051865, Shrinkage: 0.01
# Date: 2006-09-18 00:00:00, Volatility: 0.052491, Naive Volatility: 0.053476, Shrinkage: 0.01
# Date: 2006-09-19 00:00:00, Volatility: 0.051531, Naive Volatility: 0.052368, Shrinkage: 0.02
# Date: 2006-09-20 00:00:00, Volatility: 0.052577, Naive Volatility: 0.052736, Shrinkage: 0.05
# Date: 2006-09-21 00:00:00, Volatility: 0.052721, Naive Volatility: 0.052538, Shrinkage: 0.67
# Date: 2006-09-22 00:00:00, Volatility: 0.053147, Naive Volatility: 0.054385, Shrinkage: 0.74
# Date: 2006-09-25 00:00:00, Volatility: 0.052458, Naive Volatility: 0.054590, Shrinkage: 0.84
# Date: 2006-09-26 00:00:00, Volatility: 0.051602, Naive Volatility: 0.053081, Shrinkage: 0.88
# Date: 2006-09-27 00:00:00, Volatility: 0.051369, Naive Volatility: 0.052540, Shrinkage: 0.84
# Date: 2006-09-28 00:00:00, Volatility: 0.051565, Naive Volatility: 0.052027, Shrinkage: 0.78
# Date: 2006-09-29 00:00:00, Volatility: 0.053589, Naive Volatility: 0.054380, Shrinkage: 0.78
# Date: 2006-10-02 00:00:00, Volatility: 0.051278, Naive Volatility: 0.052208, Shrinkage: 0.74
# Date: 2006-10-03 00:00:00, Volatility: 0.050813, Naive Volatility: 0.051564, Shrinkage: 0.69
# Date: 2006-10-04 00:00:00, Volatility: 0.044000, Naive Volatility: 0.045182, Shrinkage: 0.59
# Date: 2006-10-05 00:00:00, Volatility: 0.044277, Naive Volatility: 0.046413, Shrinkage: 0.70
# Date: 2006-10-06 00:00:00, Volatility: 0.045100, Naive Volatility: 0.046785, Shrinkage: 0.58
# Date: 2006-10-09 00:00:00, Volatility: 0.047828, Naive Volatility: 0.049227, Shrinkage: 0.00
# Date: 2006-10-10 00:00:00, Volatility: 0.047110, Naive Volatility: 0.048162, Shrinkage: 0.00
# Date: 2006-10-11 00:00:00, Volatility: 0.046968, Naive Volatility: 0.047991, Shrinkage: 0.00
# Date: 2006-10-12 00:00:00, Volatility: 0.053931, Naive Volatility: 0.053940, Shrinkage: 0.09
# Date: 2006-10-13 00:00:00, Volatility: 0.051842, Naive Volatility: 0.051928, Shrinkage: 0.14
# Date: 2006-10-16 00:00:00, Volatility: 0.049931, Naive Volatility: 0.050182, Shrinkage: 0.15
# Date: 2006-10-17 00:00:00, Volatility: 0.050040, Naive Volatility: 0.050084, Shrinkage: 0.15
# Date: 2006-10-18 00:00:00, Volatility: 0.047108, Naive Volatility: 0.047456, Shrinkage: 0.05
# Date: 2006-10-19 00:00:00, Volatility: 0.047360, Naive Volatility: 0.048110, Shrinkage: 0.00
# Date: 2006-10-20 00:00:00, Volatility: 0.046493, Naive Volatility: 0.046951, Shrinkage: 0.03
# Date: 2006-10-23 00:00:00, Volatility: 0.042398, Naive Volatility: 0.042806, Shrinkage: 0.03
# Date: 2006-10-24 00:00:00, Volatility: 0.042774, Naive Volatility: 0.043968, Shrinkage: 0.00
# Date: 2006-10-25 00:00:00, Volatility: 0.043204, Naive Volatility: 0.044706, Shrinkage: 0.00
# Date: 2006-10-26 00:00:00, Volatility: 0.044362, Naive Volatility: 0.045720, Shrinkage: 0.00
# Date: 2006-10-27 00:00:00, Volatility: 0.050009, Naive Volatility: 0.051866, Shrinkage: 0.00
# Date: 2006-10-30 00:00:00, Volatility: 0.051131, Naive Volatility: 0.052573, Shrinkage: 0.00
# Date: 2006-10-31 00:00:00, Volatility: 0.055835, Naive Volatility: 0.056494, Shrinkage: 0.02
# Date: 2006-11-01 00:00:00, Volatility: 0.054807, Naive Volatility: 0.055430, Shrinkage: 0.02
# Date: 2006-11-02 00:00:00, Volatility: 0.053952, Naive Volatility: 0.054676, Shrinkage: 0.01
# Date: 2006-11-03 00:00:00, Volatility: 0.060414, Naive Volatility: 0.061338, Shrinkage: 0.01
# Date: 2006-11-06 00:00:00, Volatility: 0.057719, Naive Volatility: 0.058369, Shrinkage: 0.02
# Date: 2006-11-07 00:00:00, Volatility: 0.059068, Naive Volatility: 0.059336, Shrinkage: 0.05
# Date: 2006-11-08 00:00:00, Volatility: 0.059299, Naive Volatility: 0.059678, Shrinkage: 0.04
# Date: 2006-11-09 00:00:00, Volatility: 0.054948, Naive Volatility: 0.055578, Shrinkage: 0.02
# Date: 2006-11-10 00:00:00, Volatility: 0.055706, Naive Volatility: 0.056435, Shrinkage: 0.02
# Date: 2006-11-13 00:00:00, Volatility: 0.055906, Naive Volatility: 0.056706, Shrinkage: 0.00
# Date: 2006-11-14 00:00:00, Volatility: 0.054884, Naive Volatility: 0.055925, Shrinkage: 0.00
# Date: 2006-11-15 00:00:00, Volatility: 0.054748, Naive Volatility: 0.055906, Shrinkage: 0.00
# Date: 2006-11-16 00:00:00, Volatility: 0.053902, Naive Volatility: 0.055155, Shrinkage: 0.00
# Date: 2006-11-17 00:00:00, Volatility: 0.054667, Naive Volatility: 0.055982, Shrinkage: 0.01
# Date: 2006-11-20 00:00:00, Volatility: 0.053017, Naive Volatility: 0.054500, Shrinkage: 0.00
# Date: 2006-11-21 00:00:00, Volatility: 0.055584, Naive Volatility: 0.056803, Shrinkage: 0.00
# Date: 2006-11-22 00:00:00, Volatility: 0.055313, Naive Volatility: 0.056322, Shrinkage: 0.00
# Date: 2006-11-24 00:00:00, Volatility: 0.054541, Naive Volatility: 0.055508, Shrinkage: 0.00
# Date: 2006-11-27 00:00:00, Volatility: 0.046369, Naive Volatility: 0.046845, Shrinkage: 0.02
# Date: 2006-11-28 00:00:00, Volatility: 0.044576, Naive Volatility: 0.045182, Shrinkage: 0.01
# Date: 2006-11-29 00:00:00, Volatility: 0.040534, Naive Volatility: 0.041708, Shrinkage: 0.00
# Date: 2006-11-30 00:00:00, Volatility: 0.045484, Naive Volatility: 0.046095, Shrinkage: 0.00
# Date: 2006-12-01 00:00:00, Volatility: 0.045541, Naive Volatility: 0.046227, Shrinkage: 0.00
# Date: 2006-12-04 00:00:00, Volatility: 0.033698, Naive Volatility: 0.033699, Shrinkage: 0.09
# Date: 2006-12-05 00:00:00, Volatility: 0.035415, Naive Volatility: 0.035606, Shrinkage: 0.03
# Date: 2006-12-06 00:00:00, Volatility: 0.035072, Naive Volatility: 0.035254, Shrinkage: 0.03
# Date: 2006-12-07 00:00:00, Volatility: 0.034917, Naive Volatility: 0.035140, Shrinkage: 0.04
# Date: 2006-12-08 00:00:00, Volatility: 0.035579, Naive Volatility: 0.035660, Shrinkage: 0.06
# Date: 2006-12-11 00:00:00, Volatility: 0.038397, Naive Volatility: 0.038408, Shrinkage: 0.09
# Date: 2006-12-12 00:00:00, Volatility: 0.038946, Naive Volatility: 0.038966, Shrinkage: 0.11
# Date: 2006-12-13 00:00:00, Volatility: 0.038790, Naive Volatility: 0.038987, Shrinkage: 0.04
# Date: 2006-12-14 00:00:00, Volatility: 0.038431, Naive Volatility: 0.038443, Shrinkage: 0.06
# Date: 2006-12-15 00:00:00, Volatility: 0.038931, Naive Volatility: 0.038985, Shrinkage: 0.12
# Date: 2006-12-18 00:00:00, Volatility: 0.038578, Naive Volatility: 0.038778, Shrinkage: 0.20
# Date: 2006-12-19 00:00:00, Volatility: 0.038383, Naive Volatility: 0.038784, Shrinkage: 0.21
# Date: 2006-12-20 00:00:00, Volatility: 0.038753, Naive Volatility: 0.038912, Shrinkage: 0.15
# Date: 2006-12-21 00:00:00, Volatility: 0.041120, Naive Volatility: 0.041497, Shrinkage: 0.00
# Date: 2006-12-22 00:00:00, Volatility: 0.042727, Naive Volatility: 0.043841, Shrinkage: 0.00
# Date: 2006-12-26 00:00:00, Volatility: 0.042368, Naive Volatility: 0.043262, Shrinkage: 0.00
# Date: 2006-12-27 00:00:00, Volatility: 0.042606, Naive Volatility: 0.043342, Shrinkage: 0.00
# Date: 2006-12-28 00:00:00, Volatility: 0.044523, Naive Volatility: 0.044498, Shrinkage: 0.35
# Date: 2006-12-29 00:00:00, Volatility: 0.042091, Naive Volatility: 0.042423, Shrinkage: 0.34
# Date: 2007-01-03 00:00:00, Volatility: 0.043650, Naive Volatility: 0.044734, Shrinkage: 0.00
# Date: 2007-01-04 00:00:00, Volatility: 0.043252, Naive Volatility: 0.044227, Shrinkage: 0.00
# Date: 2007-01-05 00:00:00, Volatility: 0.037826, Naive Volatility: 0.038187, Shrinkage: 0.34
# Date: 2007-01-08 00:00:00, Volatility: 0.037195, Naive Volatility: 0.038117, Shrinkage: 0.35
# Date: 2007-01-09 00:00:00, Volatility: 0.037506, Naive Volatility: 0.037615, Shrinkage: 0.43
# Date: 2007-01-10 00:00:00, Volatility: 0.037224, Naive Volatility: 0.037573, Shrinkage: 0.35
# Date: 2007-01-11 00:00:00, Volatility: 0.036305, Naive Volatility: 0.037049, Shrinkage: 0.01
# Date: 2007-01-12 00:00:00, Volatility: 0.034252, Naive Volatility: 0.035782, Shrinkage: 0.00
# Date: 2007-01-16 00:00:00, Volatility: 0.035496, Naive Volatility: 0.037356, Shrinkage: 0.00
# Date: 2007-01-17 00:00:00, Volatility: 0.035250, Naive Volatility: 0.037353, Shrinkage: 0.00
# Date: 2007-01-18 00:00:00, Volatility: 0.037626, Naive Volatility: 0.040648, Shrinkage: 0.00
# Date: 2007-01-19 00:00:00, Volatility: 0.037886, Naive Volatility: 0.040641, Shrinkage: 0.00
# Date: 2007-01-22 00:00:00, Volatility: 0.036622, Naive Volatility: 0.039424, Shrinkage: 0.00
# Date: 2007-01-23 00:00:00, Volatility: 0.039491, Naive Volatility: 0.042176, Shrinkage: 0.00
# Date: 2007-01-24 00:00:00, Volatility: 0.039372, Naive Volatility: 0.041996, Shrinkage: 0.00
# Date: 2007-01-25 00:00:00, Volatility: 0.039286, Naive Volatility: 0.040727, Shrinkage: 0.00
# Date: 2007-01-26 00:00:00, Volatility: 0.038583, Naive Volatility: 0.040378, Shrinkage: 0.00
# Date: 2007-01-29 00:00:00, Volatility: 0.084344, Naive Volatility: 0.088907, Shrinkage: 0.00
# Date: 2007-01-30 00:00:00, Volatility: 0.083097, Naive Volatility: 0.088048, Shrinkage: 0.00
# Date: 2007-01-31 00:00:00, Volatility: 0.082810, Naive Volatility: 0.087962, Shrinkage: 0.00
# Date: 2007-02-01 00:00:00, Volatility: 0.085287, Naive Volatility: 0.090982, Shrinkage: 0.00
# Date: 2007-02-02 00:00:00, Volatility: 0.085128, Naive Volatility: 0.091025, Shrinkage: 0.00
# Date: 2007-02-05 00:00:00, Volatility: 0.091511, Naive Volatility: 0.096979, Shrinkage: 0.00
# Date: 2007-02-06 00:00:00, Volatility: 0.090474, Naive Volatility: 0.097086, Shrinkage: 0.00
# Date: 2007-02-07 00:00:00, Volatility: 0.092466, Naive Volatility: 0.099136, Shrinkage: 0.00
# Date: 2007-02-08 00:00:00, Volatility: 0.093879, Naive Volatility: 0.100571, Shrinkage: 0.00
# Date: 2007-02-09 00:00:00, Volatility: 0.095174, Naive Volatility: 0.101116, Shrinkage: 0.00
# Date: 2007-02-12 00:00:00, Volatility: 0.097010, Naive Volatility: 0.105037, Shrinkage: 0.00
# Date: 2007-02-13 00:00:00, Volatility: 0.096566, Naive Volatility: 0.104445, Shrinkage: 0.00
# Date: 2007-02-14 00:00:00, Volatility: 0.097396, Naive Volatility: 0.105173, Shrinkage: 0.00
# Date: 2007-02-15 00:00:00, Volatility: 0.095029, Naive Volatility: 0.102345, Shrinkage: 0.00
# Date: 2007-02-16 00:00:00, Volatility: 0.097371, Naive Volatility: 0.105310, Shrinkage: 0.00
# Date: 2007-02-20 00:00:00, Volatility: 0.099988, Naive Volatility: 0.107538, Shrinkage: 0.00
# Date: 2007-02-21 00:00:00, Volatility: 0.085575, Naive Volatility: 0.102575, Shrinkage: 0.00
# Date: 2007-02-22 00:00:00, Volatility: 0.085865, Naive Volatility: 0.102670, Shrinkage: 0.00
# Date: 2007-02-23 00:00:00, Volatility: 0.085440, Naive Volatility: 0.102670, Shrinkage: 0.00
# Date: 2007-02-26 00:00:00, Volatility: 0.084911, Naive Volatility: 0.103067, Shrinkage: 0.00
# Date: 2007-02-27 00:00:00, Volatility: 0.072182, Naive Volatility: 0.080660, Shrinkage: 0.01
# Date: 2007-02-28 00:00:00, Volatility: 0.070763, Naive Volatility: 0.078299, Shrinkage: 0.01
# Date: 2007-03-01 00:00:00, Volatility: 0.069108, Naive Volatility: 0.077079, Shrinkage: 0.01
# Date: 2007-03-02 00:00:00, Volatility: 0.064472, Naive Volatility: 0.071012, Shrinkage: 0.01
# Date: 2007-03-05 00:00:00, Volatility: 0.063749, Naive Volatility: 0.068704, Shrinkage: 0.01
# Date: 2007-03-06 00:00:00, Volatility: 0.063633, Naive Volatility: 0.066711, Shrinkage: 0.02
# Date: 2007-03-07 00:00:00, Volatility: 0.062487, Naive Volatility: 0.064537, Shrinkage: 0.03
# Date: 2007-03-08 00:00:00, Volatility: 0.061800, Naive Volatility: 0.063622, Shrinkage: 0.03
# Date: 2007-03-09 00:00:00, Volatility: 0.061476, Naive Volatility: 0.063107, Shrinkage: 0.04
# Date: 2007-03-12 00:00:00, Volatility: 0.059127, Naive Volatility: 0.061907, Shrinkage: 0.02
# Date: 2007-03-13 00:00:00, Volatility: 0.044174, Naive Volatility: 0.044609, Shrinkage: 0.07
# Date: 2007-03-14 00:00:00, Volatility: 0.041970, Naive Volatility: 0.043185, Shrinkage: 0.05
# Date: 2007-03-15 00:00:00, Volatility: 0.040893, Naive Volatility: 0.042467, Shrinkage: 0.06
# Date: 2007-03-16 00:00:00, Volatility: 0.039166, Naive Volatility: 0.041158, Shrinkage: 0.05
# Date: 2007-03-19 00:00:00, Volatility: 0.036335, Naive Volatility: 0.039109, Shrinkage: 0.03
# Date: 2007-03-20 00:00:00, Volatility: 0.033598, Naive Volatility: 0.036651, Shrinkage: 0.03
# Date: 2007-03-21 00:00:00, Volatility: 0.032709, Naive Volatility: 0.034006, Shrinkage: 0.04
# Date: 2007-03-22 00:00:00, Volatility: 0.032714, Naive Volatility: 0.034078, Shrinkage: 0.05
# Date: 2007-03-23 00:00:00, Volatility: 0.032572, Naive Volatility: 0.034146, Shrinkage: 0.04
# Date: 2007-03-26 00:00:00, Volatility: 0.032325, Naive Volatility: 0.033851, Shrinkage: 0.04
# Date: 2007-03-27 00:00:00, Volatility: 0.025236, Naive Volatility: 0.025764, Shrinkage: 0.06
# Date: 2007-03-28 00:00:00, Volatility: 0.027961, Naive Volatility: 0.028017, Shrinkage: 0.08
# Date: 2007-03-29 00:00:00, Volatility: 0.028693, Naive Volatility: 0.028790, Shrinkage: 0.08
# Date: 2007-03-30 00:00:00, Volatility: 0.032103, Naive Volatility: 0.032887, Shrinkage: 0.07
# Date: 2007-04-02 00:00:00, Volatility: 0.052679, Naive Volatility: 0.052695, Shrinkage: 0.10
# Date: 2007-04-03 00:00:00, Volatility: 0.059789, Naive Volatility: 0.058158, Shrinkage: 0.74
# Date: 2007-04-04 00:00:00, Volatility: 0.059861, Naive Volatility: 0.058679, Shrinkage: 0.74
# Date: 2007-04-05 00:00:00, Volatility: 0.059897, Naive Volatility: 0.058968, Shrinkage: 0.75
# ...
# Date: 2007-08-23 00:00:00, Volatility: 0.021690, Naive Volatility: 0.064702, Shrinkage: 0.00
# Date: 2007-08-24 00:00:00, Volatility: 0.022006, Naive Volatility: 0.064401, Shrinkage: 0.00
# Date: 2007-08-27 00:00:00, Volatility: 0.020828, Naive Volatility: 0.061548, Shrinkage: 0.00
# Date: 2007-08-28 00:00:00, Volatility: 0.079233, Naive Volatility: 0.081097, Shrinkage: 0.00
# Date: 2007-08-29 00:00:00, Volatility: 0.073184, Naive Volatility: 0.074958, Shrinkage: 0.00
# Date: 2007-08-30 00:00:00, Volatility: 0.073311, Naive Volatility: 0.074668, Shrinkage: 0.00
# Date: 2007-08-31 00:00:00, Volatility: 0.071267, Naive Volatility: 0.071874, Shrinkage: 0.00
# Date: 2007-09-04 00:00:00, Volatility: 0.068006, Naive Volatility: 0.068677, Shrinkage: 0.00
# Date: 2007-09-05 00:00:00, Volatility: 0.067011, Naive Volatility: 0.067332, Shrinkage: 0.00
# Date: 2007-09-06 00:00:00, Volatility: 0.067077, Naive Volatility: 0.067134, Shrinkage: 0.12
# Date: 2007-09-07 00:00:00, Volatility: 0.064911, Naive Volatility: 0.065024, Shrinkage: 0.12
# Date: 2007-09-10 00:00:00, Volatility: 0.066174, Naive Volatility: 0.066305, Shrinkage: 0.15
# Date: 2007-09-11 00:00:00, Volatility: 0.062924, Naive Volatility: 0.063617, Shrinkage: 0.00
# Date: 2007-09-12 00:00:00, Volatility: 0.062507, Naive Volatility: 0.063521, Shrinkage: 0.00
# Date: 2007-09-13 00:00:00, Volatility: 0.064507, Naive Volatility: 0.065536, Shrinkage: 0.00
# Date: 2007-09-14 00:00:00, Volatility: 0.065046, Naive Volatility: 0.066351, Shrinkage: 0.00
# Date: 2007-09-17 00:00:00, Volatility: 0.066707, Naive Volatility: 0.068315, Shrinkage: 0.01
# Date: 2007-09-18 00:00:00, Volatility: 0.053622, Naive Volatility: 0.054678, Shrinkage: 0.00
# Date: 2007-09-19 00:00:00, Volatility: 0.051713, Naive Volatility: 0.052376, Shrinkage: 0.01
# Date: 2007-09-20 00:00:00, Volatility: 0.052030, Naive Volatility: 0.050758, Shrinkage: 0.58
# Date: 2007-09-21 00:00:00, Volatility: 0.065053, Naive Volatility: 0.067228, Shrinkage: 0.00
# Date: 2007-09-24 00:00:00, Volatility: 0.066127, Naive Volatility: 0.067829, Shrinkage: 0.00
# Date: 2007-09-25 00:00:00, Volatility: 0.070208, Naive Volatility: 0.071517, Shrinkage: 0.00
# Date: 2007-09-26 00:00:00, Volatility: 0.068853, Naive Volatility: 0.069659, Shrinkage: 0.00
# Date: 2007-09-27 00:00:00, Volatility: 0.074017, Naive Volatility: 0.073886, Shrinkage: 0.47
# Date: 2007-09-28 00:00:00, Volatility: 0.075264, Naive Volatility: 0.075488, Shrinkage: 0.49
# Date: 2007-10-01 00:00:00, Volatility: 0.073011, Naive Volatility: 0.073997, Shrinkage: 0.63
# Date: 2007-10-02 00:00:00, Volatility: 0.074205, Naive Volatility: 0.075352, Shrinkage: 0.62
# Date: 2007-10-03 00:00:00, Volatility: 0.076063, Naive Volatility: 0.076605, Shrinkage: 0.00
# Date: 2007-10-04 00:00:00, Volatility: 0.070762, Naive Volatility: 0.081596, Shrinkage: 0.00
# Date: 2007-10-05 00:00:00, Volatility: 0.067563, Naive Volatility: 0.078944, Shrinkage: 0.00
# Date: 2007-10-08 00:00:00, Volatility: 0.069578, Naive Volatility: 0.080712, Shrinkage: 0.00
# Date: 2007-10-09 00:00:00, Volatility: 0.066056, Naive Volatility: 0.076421, Shrinkage: 0.00
# Date: 2007-10-10 00:00:00, Volatility: 0.074698, Naive Volatility: 0.085086, Shrinkage: 0.00
# Date: 2007-10-11 00:00:00, Volatility: 0.089435, Naive Volatility: 0.096891, Shrinkage: 0.00
# Date: 2007-10-12 00:00:00, Volatility: 0.088601, Naive Volatility: 0.095760, Shrinkage: 0.00
# Date: 2007-10-15 00:00:00, Volatility: 0.088673, Naive Volatility: 0.095454, Shrinkage: 0.00
# Date: 2007-10-16 00:00:00, Volatility: 0.093162, Naive Volatility: 0.102389, Shrinkage: 0.00
# Date: 2007-10-17 00:00:00, Volatility: 0.094360, Naive Volatility: 0.102795, Shrinkage: 0.00
# Date: 2007-10-18 00:00:00, Volatility: 0.094133, Naive Volatility: 0.102904, Shrinkage: 0.00
# Date: 2007-10-19 00:00:00, Volatility: 0.088936, Naive Volatility: 0.095907, Shrinkage: 0.00
# Date: 2007-10-22 00:00:00, Volatility: 0.090762, Naive Volatility: 0.098258, Shrinkage: 0.00
# Date: 2007-10-23 00:00:00, Volatility: 0.090748, Naive Volatility: 0.096331, Shrinkage: 0.00
# Date: 2007-10-24 00:00:00, Volatility: 0.093006, Naive Volatility: 0.098882, Shrinkage: 0.00
# Date: 2007-10-25 00:00:00, Volatility: 0.093928, Naive Volatility: 0.099173, Shrinkage: 0.00
# Date: 2007-10-26 00:00:00, Volatility: 0.093069, Naive Volatility: 0.097045, Shrinkage: 0.01
# Date: 2007-10-29 00:00:00, Volatility: 0.097527, Naive Volatility: 0.101955, Shrinkage: 0.01
# Date: 2007-10-30 00:00:00, Volatility: 0.095469, Naive Volatility: 0.107596, Shrinkage: 0.00
# Date: 2007-10-31 00:00:00, Volatility: 0.093560, Naive Volatility: 0.106208, Shrinkage: 0.00
# Date: 2007-11-01 00:00:00, Volatility: 0.088705, Naive Volatility: 0.098374, Shrinkage: 0.00
# Date: 2007-11-02 00:00:00, Volatility: 0.088364, Naive Volatility: 0.097363, Shrinkage: 0.00
# Date: 2007-11-05 00:00:00, Volatility: 0.088098, Naive Volatility: 0.097757, Shrinkage: 0.00
# Date: 2007-11-06 00:00:00, Volatility: 0.088493, Naive Volatility: 0.099050, Shrinkage: 0.00
# Date: 2007-11-07 00:00:00, Volatility: 0.082207, Naive Volatility: 0.092516, Shrinkage: 0.00
# Date: 2007-11-08 00:00:00, Volatility: 0.076903, Naive Volatility: 0.088349, Shrinkage: 0.00
# Date: 2007-11-09 00:00:00, Volatility: 0.080191, Naive Volatility: 0.089259, Shrinkage: 0.00
# Date: 2007-11-12 00:00:00, Volatility: 0.085149, Naive Volatility: 0.100503, Shrinkage: 0.00
# Date: 2007-11-13 00:00:00, Volatility: 0.077864, Naive Volatility: 0.091396, Shrinkage: 0.00
# Date: 2007-11-14 00:00:00, Volatility: 0.073138, Naive Volatility: 0.086418, Shrinkage: 0.00
# Date: 2007-11-15 00:00:00, Volatility: 0.074378, Naive Volatility: 0.086955, Shrinkage: 0.00
# Date: 2007-11-16 00:00:00, Volatility: 0.076885, Naive Volatility: 0.089187, Shrinkage: 0.00
# Date: 2007-11-19 00:00:00, Volatility: 0.069287, Naive Volatility: 0.081665, Shrinkage: 0.00
# Date: 2007-11-20 00:00:00, Volatility: 0.072515, Naive Volatility: 0.090435, Shrinkage: 0.00
# Date: 2007-11-21 00:00:00, Volatility: 0.068001, Naive Volatility: 0.086063, Shrinkage: 0.00
# Date: 2007-11-23 00:00:00, Volatility: 0.065715, Naive Volatility: 0.084203, Shrinkage: 0.00
# Date: 2007-11-26 00:00:00, Volatility: 0.063599, Naive Volatility: 0.081532, Shrinkage: 0.00
# Date: 2007-11-27 00:00:00, Volatility: 0.054070, Naive Volatility: 0.074916, Shrinkage: 0.00
# Date: 2007-11-28 00:00:00, Volatility: 0.052935, Naive Volatility: 0.069979, Shrinkage: 0.00
# Date: 2007-11-29 00:00:00, Volatility: 0.050233, Naive Volatility: 0.064351, Shrinkage: 0.00
# Date: 2007-11-30 00:00:00, Volatility: 0.050635, Naive Volatility: 0.065255, Shrinkage: 0.00
# Date: 2007-12-03 00:00:00, Volatility: 0.051563, Naive Volatility: 0.069401, Shrinkage: 0.00
# Date: 2007-12-04 00:00:00, Volatility: 0.051225, Naive Volatility: 0.069014, Shrinkage: 0.00
# Date: 2007-12-05 00:00:00, Volatility: 0.049837, Naive Volatility: 0.063826, Shrinkage: 0.00
# Date: 2007-12-06 00:00:00, Volatility: 0.049465, Naive Volatility: 0.066160, Shrinkage: 0.00
# Date: 2007-12-07 00:00:00, Volatility: 0.051071, Naive Volatility: 0.068554, Shrinkage: 0.00
# Date: 2007-12-10 00:00:00, Volatility: 0.060746, Naive Volatility: 0.080186, Shrinkage: 0.00
# Date: 2007-12-11 00:00:00, Volatility: 0.061943, Naive Volatility: 0.080834, Shrinkage: 0.00
# Date: 2007-12-12 00:00:00, Volatility: 0.067852, Naive Volatility: 0.090296, Shrinkage: 0.00
# Date: 2007-12-13 00:00:00, Volatility: 0.069157, Naive Volatility: 0.090512, Shrinkage: 0.00
# Date: 2007-12-14 00:00:00, Volatility: 0.066658, Naive Volatility: 0.093218, Shrinkage: 0.00
# Date: 2007-12-17 00:00:00, Volatility: 0.063617, Naive Volatility: 0.091125, Shrinkage: 0.00
# Date: 2007-12-18 00:00:00, Volatility: 0.077772, Naive Volatility: 0.098938, Shrinkage: 0.00
# Date: 2007-12-19 00:00:00, Volatility: 0.080490, Naive Volatility: 0.101714, Shrinkage: 0.00
# Date: 2007-12-20 00:00:00, Volatility: 0.079807, Naive Volatility: 0.100942, Shrinkage: 0.01
# Date: 2007-12-21 00:00:00, Volatility: 0.079922, Naive Volatility: 0.100655, Shrinkage: 0.00
# Date: 2007-12-24 00:00:00, Volatility: 0.078357, Naive Volatility: 0.100297, Shrinkage: 0.01
# Date: 2007-12-26 00:00:00, Volatility: 0.078266, Naive Volatility: 0.100710, Shrinkage: 0.00
# Date: 2007-12-27 00:00:00, Volatility: 0.079059, Naive Volatility: 0.102763, Shrinkage: 0.00
# Date: 2007-12-28 00:00:00, Volatility: 0.079217, Naive Volatility: 0.101949, Shrinkage: 0.00
# Date: 2007-12-31 00:00:00, Volatility: 0.079364, Naive Volatility: 0.102144, Shrinkage: 0.00
# Date: 2008-01-02 00:00:00, Volatility: 0.079718, Naive Volatility: 0.105408, Shrinkage: 0.00
# Date: 2008-01-03 00:00:00, Volatility: 0.080726, Naive Volatility: 0.114179, Shrinkage: 0.00
# Date: 2008-01-04 00:00:00, Volatility: 0.080071, Naive Volatility: 0.114501, Shrinkage: 0.00
# Date: 2008-01-07 00:00:00, Volatility: 0.079923, Naive Volatility: 0.112150, Shrinkage: 0.00
# Date: 2008-01-08 00:00:00, Volatility: 0.079501, Naive Volatility: 0.110159, Shrinkage: 0.00
# Date: 2008-01-09 00:00:00, Volatility: 0.072064, Naive Volatility: 0.100387, Shrinkage: 0.00
# Date: 2008-01-10 00:00:00, Volatility: 0.070896, Naive Volatility: 0.098017, Shrinkage: 0.01
# Date: 2008-01-11 00:00:00, Volatility: 0.065993, Naive Volatility: 0.097833, Shrinkage: 0.01
# Date: 2008-01-14 00:00:00, Volatility: 0.061208, Naive Volatility: 0.099564, Shrinkage: 0.00
# Date: 2008-01-15 00:00:00, Volatility: 0.063328, Naive Volatility: 0.099034, Shrinkage: 0.00
# Date: 2008-01-16 00:00:00, Volatility: 0.063086, Naive Volatility: 0.097587, Shrinkage: 0.00
# Date: 2008-01-17 00:00:00, Volatility: 0.045448, Naive Volatility: 0.090894, Shrinkage: 0.00
# Date: 2008-01-18 00:00:00, Volatility: 0.039743, Naive Volatility: 0.086722, Shrinkage: 0.00
# Date: 2008-01-22 00:00:00, Volatility: 0.035369, Naive Volatility: 0.081422, Shrinkage: 0.00
# Date: 2008-01-23 00:00:00, Volatility: 0.036714, Naive Volatility: 0.086199, Shrinkage: 0.00
# Date: 2008-01-24 00:00:00, Volatility: 0.036861, Naive Volatility: 0.088215, Shrinkage: 0.00
# Date: 2008-01-25 00:00:00, Volatility: 0.037276, Naive Volatility: 0.090005, Shrinkage: 0.00
# Date: 2008-01-28 00:00:00, Volatility: 0.035330, Naive Volatility: 0.091381, Shrinkage: 0.00
# Date: 2008-01-29 00:00:00, Volatility: 0.140397, Naive Volatility: 0.157165, Shrinkage: 0.63
# Date: 2008-01-30 00:00:00, Volatility: 0.143644, Naive Volatility: 0.161412, Shrinkage: 0.67
# Date: 2008-01-31 00:00:00, Volatility: 0.152526, Naive Volatility: 0.164792, Shrinkage: 0.64
# Date: 2008-02-01 00:00:00, Volatility: 0.137814, Naive Volatility: 0.147779, Shrinkage: 0.64
# Date: 2008-02-04 00:00:00, Volatility: 0.134609, Naive Volatility: 0.141811, Shrinkage: 0.52
# Date: 2008-02-05 00:00:00, Volatility: 0.121832, Naive Volatility: 0.133742, Shrinkage: 0.64
# Date: 2008-02-06 00:00:00, Volatility: 0.133230, Naive Volatility: 0.137509, Shrinkage: 0.45
# Date: 2008-02-07 00:00:00, Volatility: 0.133019, Naive Volatility: 0.139436, Shrinkage: 0.46
# Date: 2008-02-08 00:00:00, Volatility: 0.133761, Naive Volatility: 0.138935, Shrinkage: 0.46
# Date: 2008-02-11 00:00:00, Volatility: 0.134565, Naive Volatility: 0.141987, Shrinkage: 0.42
# Date: 2008-02-12 00:00:00, Volatility: 0.130195, Naive Volatility: 0.135833, Shrinkage: 0.41
# Date: 2008-02-13 00:00:00, Volatility: 0.128390, Naive Volatility: 0.134872, Shrinkage: 0.42
# Date: 2008-02-14 00:00:00, Volatility: 0.131599, Naive Volatility: 0.136410, Shrinkage: 0.38
# Date: 2008-02-15 00:00:00, Volatility: 0.129955, Naive Volatility: 0.131373, Shrinkage: 0.34
# Date: 2008-02-19 00:00:00, Volatility: 0.165987, Naive Volatility: 0.167431, Shrinkage: 0.43
# Date: 2008-02-20 00:00:00, Volatility: 0.169462, Naive Volatility: 0.175417, Shrinkage: 0.45
# Date: 2008-02-21 00:00:00, Volatility: 0.169058, Naive Volatility: 0.172708, Shrinkage: 0.41
# Date: 2008-02-22 00:00:00, Volatility: 0.168001, Naive Volatility: 0.168277, Shrinkage: 0.31
# Date: 2008-02-25 00:00:00, Volatility: 0.161455, Naive Volatility: 0.161652, Shrinkage: 0.35
# Date: 2008-02-26 00:00:00, Volatility: 0.163685, Naive Volatility: 0.166619, Shrinkage: 0.39
# Date: 2008-02-27 00:00:00, Volatility: 0.163137, Naive Volatility: 0.164987, Shrinkage: 0.38
# Date: 2008-02-28 00:00:00, Volatility: 0.161934, Naive Volatility: 0.163538, Shrinkage: 0.40
# Date: 2008-02-29 00:00:00, Volatility: 0.146537, Naive Volatility: 0.148320, Shrinkage: 0.02
# Date: 2008-03-03 00:00:00, Volatility: 0.162516, Naive Volatility: 0.163904, Shrinkage: 0.02
# Date: 2008-03-04 00:00:00, Volatility: 0.164329, Naive Volatility: 0.164329, Shrinkage: 0.10
# Date: 2008-03-05 00:00:00, Volatility: 0.162157, Naive Volatility: 0.162165, Shrinkage: 0.10
# Date: 2008-03-06 00:00:00, Volatility: 0.154669, Naive Volatility: 0.154780, Shrinkage: 0.13
# Date: 2008-03-07 00:00:00, Volatility: 0.153658, Naive Volatility: 0.154603, Shrinkage: 0.29
# Date: 2008-03-10 00:00:00, Volatility: 0.154012, Naive Volatility: 0.156410, Shrinkage: 0.34
# Date: 2008-03-11 00:00:00, Volatility: 0.150348, Naive Volatility: 0.149830, Shrinkage: 0.24
# Date: 2008-03-12 00:00:00, Volatility: 0.143039, Naive Volatility: 0.148142, Shrinkage: 0.00
# Date: 2008-03-13 00:00:00, Volatility: 0.147062, Naive Volatility: 0.152223, Shrinkage: 0.00
# Date: 2008-03-14 00:00:00, Volatility: 0.147457, Naive Volatility: 0.147472, Shrinkage: 0.30
# Date: 2008-03-17 00:00:00, Volatility: 0.145162, Naive Volatility: 0.148110, Shrinkage: 0.46
# Date: 2008-03-18 00:00:00, Volatility: 0.117134, Naive Volatility: 0.117826, Shrinkage: 0.29
# Date: 2008-03-19 00:00:00, Volatility: 0.093844, Naive Volatility: 0.097656, Shrinkage: 0.00
# Date: 2008-03-20 00:00:00, Volatility: 0.096554, Naive Volatility: 0.098182, Shrinkage: 0.01
# Date: 2008-03-24 00:00:00, Volatility: 0.095271, Naive Volatility: 0.097560, Shrinkage: 0.00
# Date: 2008-03-25 00:00:00, Volatility: 0.096411, Naive Volatility: 0.098605, Shrinkage: 0.00
# Date: 2008-03-26 00:00:00, Volatility: 0.098635, Naive Volatility: 0.099490, Shrinkage: 0.00
# Date: 2008-03-27 00:00:00, Volatility: 0.097993, Naive Volatility: 0.101307, Shrinkage: 0.00
# Date: 2008-03-28 00:00:00, Volatility: 0.096462, Naive Volatility: 0.100116, Shrinkage: 0.00
# Date: 2008-03-31 00:00:00, Volatility: 0.096080, Naive Volatility: 0.099497, Shrinkage: 0.00
# Date: 2008-04-01 00:00:00, Volatility: 0.066172, Naive Volatility: 0.068712, Shrinkage: 0.00
# Date: 2008-04-02 00:00:00, Volatility: 0.060987, Naive Volatility: 0.065066, Shrinkage: 0.00
# Date: 2008-04-03 00:00:00, Volatility: 0.079401, Naive Volatility: 0.088163, Shrinkage: 0.00
# Date: 2008-04-04 00:00:00, Volatility: 0.080278, Naive Volatility: 0.088325, Shrinkage: 0.00
# Date: 2008-04-07 00:00:00, Volatility: 0.079698, Naive Volatility: 0.087675, Shrinkage: 0.00
# Date: 2008-04-08 00:00:00, Volatility: 0.079408, Naive Volatility: 0.087292, Shrinkage: 0.00
# Date: 2008-04-09 00:00:00, Volatility: 0.086778, Naive Volatility: 0.094770, Shrinkage: 0.00
# Date: 2008-04-10 00:00:00, Volatility: 0.086152, Naive Volatility: 0.094485, Shrinkage: 0.00
# Date: 2008-04-11 00:00:00, Volatility: 0.083749, Naive Volatility: 0.091929, Shrinkage: 0.00
# Date: 2008-04-14 00:00:00, Volatility: 0.085863, Naive Volatility: 0.093727, Shrinkage: 0.00
# Date: 2008-04-15 00:00:00, Volatility: 0.085473, Naive Volatility: 0.093243, Shrinkage: 0.00
# Date: 2008-04-16 00:00:00, Volatility: 0.085747, Naive Volatility: 0.092799, Shrinkage: 0.00
# Date: 2008-04-17 00:00:00, Volatility: 0.083957, Naive Volatility: 0.091106, Shrinkage: 0.00
# Date: 2008-04-18 00:00:00, Volatility: 0.083850, Naive Volatility: 0.090558, Shrinkage: 0.00
# Date: 2008-04-21 00:00:00, Volatility: 0.081424, Naive Volatility: 0.089348, Shrinkage: 0.00
# Date: 2008-04-22 00:00:00, Volatility: 0.080615, Naive Volatility: 0.086430, Shrinkage: 0.00
# Date: 2008-04-23 00:00:00, Volatility: 0.078804, Naive Volatility: 0.084592, Shrinkage: 0.00
# Date: 2008-04-24 00:00:00, Volatility: 0.080862, Naive Volatility: 0.087680, Shrinkage: 0.00
# Date: 2008-04-25 00:00:00, Volatility: 0.087963, Naive Volatility: 0.094969, Shrinkage: 0.00
# Date: 2008-04-28 00:00:00, Volatility: 0.089307, Naive Volatility: 0.097925, Shrinkage: 0.00
# Date: 2008-04-29 00:00:00, Volatility: 0.087871, Naive Volatility: 0.097534, Shrinkage: 0.00
