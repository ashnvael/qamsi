# %%
import pandas as pd

from qamsi.utils.data import read_csv

dataset = read_csv("../../data/output/", "top30_data_df.csv")

# %%
dataset.head()
# Out:
#             10078  10104  10107  10147     10401     10604  11042  11081  \
# date
# 1980-01-02    NaN    NaN    NaN    NaN -0.002398 -0.018750    NaN    NaN
# 1980-01-03    NaN    NaN    NaN    NaN -0.004808 -0.012739    NaN    NaN
# 1980-01-04    NaN    NaN    NaN    NaN  0.000000  0.012903    NaN    NaN
# 1980-01-07    NaN    NaN    NaN    NaN  0.000000  0.015924    NaN    NaN
# 1980-01-08    NaN    NaN    NaN    NaN  0.012077  0.028213    NaN    NaN
#
#                11308     11471  ...  vol  naive_vol  target  avg_corr  \
# date                            ...
# 1980-01-02 -0.021739 -0.021164  ...  NaN        NaN     NaN       NaN
# 1980-01-03  0.025926 -0.043243  ...  NaN        NaN     NaN  0.259770
# 1980-01-04  0.010830  0.025424  ...  NaN        NaN     NaN  0.638233
# 1980-01-07 -0.003571 -0.005510  ...  NaN        NaN     NaN  0.588472
# 1980-01-08  0.007168  0.024931  ...  NaN        NaN     NaN  0.682114
#
# ...

# %%
dataset.drop(columns=["spx_fut", "end_date", "vol", "naive_vol", "target", "avg_corr", "avg_vol", "ewma", "lw_shrinkage", "momentum_feature", "trace", "universe_vol"]).to_parquet("returns_df.parquet")

# %%
import pandas as pd

data = pd.read_parquet("returns_df.parquet")
data.head()
# Out:
#             10078  10104  10107  10147     10401     10604  11042  11081  \
# date
# 1980-01-02    NaN    NaN    NaN    NaN -0.002398 -0.018750    NaN    NaN
# 1980-01-03    NaN    NaN    NaN    NaN -0.004808 -0.012739    NaN    NaN
# 1980-01-04    NaN    NaN    NaN    NaN  0.000000  0.012903    NaN    NaN
# 1980-01-07    NaN    NaN    NaN    NaN  0.000000  0.015924    NaN    NaN
# 1980-01-08    NaN    NaN    NaN    NaN  0.012077  0.028213    NaN    NaN
#
#                11308     11471  ...  92655  93002  93436  low_risk  momentum  \
# date                            ...
# 1980-01-02 -0.021739 -0.021164  ...    NaN    NaN    NaN  0.015975 -0.011926
# 1980-01-03  0.025926 -0.043243  ...    NaN    NaN    NaN  0.001756 -0.003526
# 1980-01-04  0.010830  0.025424  ...    NaN    NaN    NaN -0.013127  0.006504
# 1980-01-07 -0.003571 -0.005510  ...    NaN    NaN    NaN -0.003428  0.004751
# 1980-01-08  0.007168  0.024931  ...    NaN    NaN    NaN -0.006439  0.002184
#
# ...

# %%
pm = read_csv("../../data/output/", "top30_presence_matrix.csv")
pm.to_parquet("presence_matrix.parquet")
