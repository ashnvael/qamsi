# %%
import numpy as np
import pandas as pd
from statsmodels.datasets import grunfeld
data = grunfeld.load_pandas().data
data.year = data.year.astype(np.int64)

# Establish unique IDs to conform with package
N = len(np.unique(data.firm))
ID = dict(zip(np.unique(data.firm).tolist(),np.arange(1,N+1)))
data.firm = data.firm.apply(lambda x: ID[x])

# use multi-index for panel groups
data = data.set_index(['firm', 'year'])
y = data['invest']
X = data.drop('invest', axis=1)

# Call ipca
from ipca import InstrumentedPCA
regr = InstrumentedPCA(n_factors=1, intercept=False)
regr = regr.fit(X=X, y=y)
Gamma, Factors = regr.get_factors(label_ind=True)
# Out:
# [========================================================================] 100%
# The panel dimensions are:
# n_samples: 11 , L: 2 , T: 20
# Step 1 - Aggregate Update: 991040.1067154529
# Step 2 - Aggregate Update: 0.03116845703445048
# Step 3 - Aggregate Update: 0.013774627857861516
# Step 4 - Aggregate Update: 0.006045637463264697
# Step 5 - Aggregate Update: 0.002646397095048436
# Step 6 - Aggregate Update: 0.0011571703804043043
# Step 7 - Aggregate Update: 0.0005057548444745708
# Step 8 - Aggregate Update: 0.0002210022866247774
# Step 9 - Aggregate Update: 9.656419373532676e-05
# Step 10 - Aggregate Update: 4.219093867988133e-05
# Step 11 - Aggregate Update: 1.843381188348925e-05
# Step 12 - Aggregate Update: 8.053932978979716e-06
# -- Convergence Reached --

# %%
data
# Out:
#             invest     value  capital
# firm year
# 6    1935  317.600  3078.500    2.800
#      1936  391.800  4661.700   52.600
#      1937  410.600  5387.100  156.900
#      1938  257.700  2792.200  209.200
#      1939  330.800  4313.200  203.400
# ...            ...       ...      ...
# 1    1950    4.770    36.494   75.847
#      1951    6.532    46.082   77.367
#      1952    7.329    57.616   78.631
#      1953    9.020    57.441   80.215
#      1954    6.281    47.165   83.788
#
# [220 rows x 3 columns]

# %%
data = grunfeld.load_pandas().data
data.year = data.year.astype(np.int64)
data
# Out:
#       invest     value  capital            firm  year
# 0    317.600  3078.500    2.800  General Motors  1935
# 1    391.800  4661.700   52.600  General Motors  1936
# 2    410.600  5387.100  156.900  General Motors  1937
# 3    257.700  2792.200  209.200  General Motors  1938
# 4    330.800  4313.200  203.400  General Motors  1939
# ..       ...       ...      ...             ...   ...
# 215    4.770    36.494   75.847  American Steel  1950
# 216    6.532    46.082   77.367  American Steel  1951
# 217    7.329    57.616   78.631  American Steel  1952
# 218    9.020    57.441   80.215  American Steel  1953
# 219    6.281    47.165   83.788  American Steel  1954
#
# [220 rows x 5 columns]

# %%
md = pd.read_parquet("market_data.parquet")
md.head()
# Out:
#                price        mktcap  liquidity sector
# date       id
# 1999-05-06 1   461.0  1.235952e+09   129080.0   None
# 1999-05-07 1   455.0  1.219866e+09     4550.0   None
# 1999-05-10 1   455.0  1.219866e+09      910.0   None
# 1999-05-11 1   460.0  1.233271e+09     4600.0   None
# 1999-05-12 1   460.0  1.233271e+09      460.0   None

# %%
from config.experiment_config import ExperimentConfig

data_df = pd.read_csv(ExperimentConfig.PATH_OUTPUT / ExperimentConfig.DF_FILENAME)
data_df.head()
# Out:
#    Unnamed: 0        date       EDS  CBB  AAL         X      PCAR  SII  \
# 0           0  2004-03-22 -0.010262  NaN  NaN -0.027732 -0.008479  NaN
# 1           1  2004-03-23 -0.003110  NaN  NaN  0.002824 -0.011340  NaN
# 2           2  2004-03-24 -0.009360  NaN  NaN -0.029287  0.003385  NaN
# 3           3  2004-03-25  0.002625  NaN  NaN  0.011024  0.025675  NaN
# 4           4  2004-03-26  0.005236  NaN  NaN  0.038738 -0.002558  NaN
#
#         NUE      CINF  ...  inflation_total_r    spread      tail        ts  \
# 0 -0.026502 -0.005893  ...           0.005008  1.227273 -0.009000 -0.010733
# 1  0.023428 -0.008891  ...          -0.000760 -0.734694 -0.001816 -0.002406
# 2 -0.036756 -0.000236  ...          -0.001592  1.076923 -0.002224  0.009065
# 3  0.027280  0.004250  ...          -0.004365  1.111111  0.011348  0.006375
# 4  0.010101 -0.008229  ...          -0.003839 -1.035088 -0.002204 -0.003840
#
#    low_risk  momentum   quality      size     value       ^VIX
# 0  0.010070 -0.004480  0.002255 -0.005556  0.006790  21.580000
# 1  0.001321  0.001231  0.001307  0.001870  0.001374  20.670000
# 2 -0.002535 -0.001107  0.002863 -0.000396 -0.004048  19.809999
# 3 -0.014668  0.000857  0.001405  0.004555 -0.010705  17.879999
# 4 -0.003715  0.004026 -0.002044  0.002799 -0.000894  17.330000
#
# [5 rows x 2868 columns]

# %%
data_df["date"] = pd.to_datetime(data_df["date"])
data_df = data_df.set_index("date")

# %%
import yfinance as yfin

data = yfin.download("^VIX", ExperimentConfig.TRAIN_START_DATE, ExperimentConfig.TEST_END_DATE)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open Volume
# Ticker           ^VIX       ^VIX       ^VIX       ^VIX   ^VIX
# Date
# 2000-02-08  21.250000  22.080000  21.170000  21.680000      0
# 2000-02-09  22.900000  22.900000  21.290001  21.540001      0
# 2000-02-10  23.070000  23.549999  22.750000  23.360001      0
# 2000-02-11  24.420000  24.799999  22.820000  22.940001      0
# 2000-02-14  24.379999  24.889999  24.270000  24.670000      0
# ...               ...        ...        ...        ...    ...
# 2025-02-27  21.129999  21.469999  17.670000  18.250000      0
# 2025-02-28  19.629999  22.400000  19.049999  21.209999      0
# 2025-03-03  22.780001  24.309999  19.250000  19.830000      0
# 2025-03-04  23.510000  26.350000  21.709999  22.959999      0
# 2025-03-05  21.930000  24.840000  21.370001  23.030001      0
#
# [6306 rows x 5 columns]

# %%
data_df.merge(data["Close"], left_index=True, right_index=True)
# Out:
#                  EDS  CBB  AAL         X      PCAR  SII       NUE      CINF  \
# 2004-03-22 -0.010262  NaN  NaN -0.027732 -0.008479  NaN -0.026502 -0.005893
# 2004-03-23 -0.003110  NaN  NaN  0.002824 -0.011340  NaN  0.023428 -0.008891
# 2004-03-24 -0.009360  NaN  NaN -0.029287  0.003385  NaN -0.036756 -0.000236
# 2004-03-25  0.002625  NaN  NaN  0.011024  0.025675  NaN  0.027280  0.004250
# 2004-03-26  0.005236  NaN  NaN  0.038738 -0.002558  NaN  0.010101 -0.008229
# ...              ...  ...  ...       ...       ...  ...       ...       ...
# 2024-12-24       NaN  NaN  NaN       NaN  0.004585  NaN  0.007032  0.016585
# 2024-12-26       NaN  NaN  NaN       NaN  0.002377  NaN  0.010304  0.000275
# 2024-12-27       NaN  NaN  NaN       NaN -0.008157  NaN -0.011463 -0.008671
# 2024-12-30       NaN  NaN  NaN       NaN -0.009180  NaN -0.012108 -0.006317
# 2024-12-31       NaN  NaN  NaN       NaN  0.003957  NaN  0.012084  0.003912
#
#                   PG       CMG  ...  inflation_total_r    spread      tail  \
# 2004-03-22 -0.000577       NaN  ...           0.005008  1.227273 -0.009000
# 2004-03-23 -0.005867       NaN  ...          -0.000760 -0.734694 -0.001816
# 2004-03-24 -0.003290       NaN  ...          -0.001592  1.076923 -0.002224
# 2004-03-25  0.014755       NaN  ...          -0.004365  1.111111  0.011348
# 2004-03-26 -0.005644       NaN  ...          -0.003839 -1.035088 -0.002204
# ...              ...       ...  ...                ...       ...       ...
# 2024-12-24  0.004937  0.010718  ...           0.000512  0.167912  0.009571
# 2024-12-26  0.007222 -0.012372  ...          -0.000290  0.121800 -0.000379
# 2024-12-27 -0.003702 -0.011225  ...          -0.000662 -0.273056 -0.010186
# 2024-12-30 -0.014393 -0.011352  ...          -0.000241  0.171070 -0.009888
# 2024-12-31  0.003351  0.003495  ...           0.000894 -0.034398 -0.004064
#
#                   ts  low_risk  momentum   quality      size     value  \
# 2004-03-22 -0.010733  0.010070 -0.004480  0.002255 -0.005556  0.006790
# 2004-03-23 -0.002406  0.001321  0.001231  0.001307  0.001870  0.001374
# 2004-03-24  0.009065 -0.002535 -0.001107  0.002863 -0.000396 -0.004048
# 2004-03-25  0.006375 -0.014668  0.000857  0.001405  0.004555 -0.010705
# 2004-03-26 -0.003840 -0.003715  0.004026 -0.002044  0.002799 -0.000894
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.032535 -0.003275  0.001742 -0.000836  0.001441 -0.002167
# 2024-12-26  0.000840 -0.003629 -0.000382 -0.002163  0.008920 -0.000932
# 2024-12-27  0.170322  0.007336 -0.004039  0.000551 -0.003385  0.005571
# 2024-12-30 -0.013963  0.003767  0.000817 -0.000671  0.002048  0.005083
# 2024-12-31  0.126233  0.004087 -0.005310 -0.001124  0.001976  0.006728
#
#                  ^VIX
# 2004-03-22  21.580000
# 2004-03-23  20.670000
# 2004-03-24  19.809999
# 2004-03-25  17.879999
# 2004-03-26  17.330000
# ...               ...
# 2024-12-24  14.270000
# 2024-12-26  14.730000
# 2024-12-27  15.950000
# 2024-12-30  17.400000
# 2024-12-31  17.350000
#
# [5231 rows x 2866 columns]

# %%
# data_df.merge(data["Close"], left_index=True, right_index=True).to_csv(ExperimentConfig.PATH_OUTPUT / ExperimentConfig.DF_FILENAME)

# %%
data_df = data_df.rename(columns={"Unnamed: 0": "date"})
data_df
# Out:
#             date       EDS  CBB  AAL         X      PCAR  SII       NUE  \
# 0     2004-03-22 -0.010262  NaN  NaN -0.027732 -0.008479  NaN -0.026502
# 1     2004-03-23 -0.003110  NaN  NaN  0.002824 -0.011340  NaN  0.023428
# 2     2004-03-24 -0.009360  NaN  NaN -0.029287  0.003385  NaN -0.036756
# 3     2004-03-25  0.002625  NaN  NaN  0.011024  0.025675  NaN  0.027280
# 4     2004-03-26  0.005236  NaN  NaN  0.038738 -0.002558  NaN  0.010101
# ...          ...       ...  ...  ...       ...       ...  ...       ...
# 5226  2024-12-24       NaN  NaN  NaN       NaN  0.004585  NaN  0.007032
# 5227  2024-12-26       NaN  NaN  NaN       NaN  0.002377  NaN  0.010304
# 5228  2024-12-27       NaN  NaN  NaN       NaN -0.008157  NaN -0.011463
# 5229  2024-12-30       NaN  NaN  NaN       NaN -0.009180  NaN -0.012108
# 5230  2024-12-31       NaN  NaN  NaN       NaN  0.003957  NaN  0.012084
#
#           CINF        PG  ...  inflation_total_r    spread      tail  \
# 0    -0.005893 -0.000577  ...           0.005008  1.227273 -0.009000
# 1    -0.008891 -0.005867  ...          -0.000760 -0.734694 -0.001816
# 2    -0.000236 -0.003290  ...          -0.001592  1.076923 -0.002224
# 3     0.004250  0.014755  ...          -0.004365  1.111111  0.011348
# 4    -0.008229 -0.005644  ...          -0.003839 -1.035088 -0.002204
# ...        ...       ...  ...                ...       ...       ...
# 5226  0.016585  0.004937  ...           0.000512  0.167912  0.009571
# 5227  0.000275  0.007222  ...          -0.000290  0.121800 -0.000379
# 5228 -0.008671 -0.003702  ...          -0.000662 -0.273056 -0.010186
# 5229 -0.006317 -0.014393  ...          -0.000241  0.171070 -0.009888
# 5230  0.003912  0.003351  ...           0.000894 -0.034398 -0.004064
#
#             ts  low_risk  momentum   quality      size     value       ^VIX
# 0    -0.010733  0.010070 -0.004480  0.002255 -0.005556  0.006790  21.580000
# 1    -0.002406  0.001321  0.001231  0.001307  0.001870  0.001374  20.670000
# 2     0.009065 -0.002535 -0.001107  0.002863 -0.000396 -0.004048  19.809999
# 3     0.006375 -0.014668  0.000857  0.001405  0.004555 -0.010705  17.879999
# 4    -0.003840 -0.003715  0.004026 -0.002044  0.002799 -0.000894  17.330000
# ...        ...       ...       ...       ...       ...       ...        ...
# 5226  0.032535 -0.003275  0.001742 -0.000836  0.001441 -0.002167  14.270000
# 5227  0.000840 -0.003629 -0.000382 -0.002163  0.008920 -0.000932  14.730000
# 5228  0.170322  0.007336 -0.004039  0.000551 -0.003385  0.005571  15.950000
# 5229 -0.013963  0.003767  0.000817 -0.000671  0.002048  0.005083  17.400000
# 5230  0.126233  0.004087 -0.005310 -0.001124  0.001976  0.006728  17.350000
#
# [5231 rows x 2867 columns]

# %%
data_df.to_csv(ExperimentConfig.PATH_OUTPUT / ExperimentConfig.DF_FILENAME, index=False)

# %%
data_df["spx_vol"] = data_df["spx"] ** 2

# %%
data_df = data_df.drop("Unnamed: 0", axis=1)

# %%
data_df
# Out:
#             date       EDS  CBB  AAL         X      PCAR  SII       NUE  \
# 0     2004-03-22 -0.010262  NaN  NaN -0.027732 -0.008479  NaN -0.026502
# 1     2004-03-23 -0.003110  NaN  NaN  0.002824 -0.011340  NaN  0.023428
# 2     2004-03-24 -0.009360  NaN  NaN -0.029287  0.003385  NaN -0.036756
# 3     2004-03-25  0.002625  NaN  NaN  0.011024  0.025675  NaN  0.027280
# 4     2004-03-26  0.005236  NaN  NaN  0.038738 -0.002558  NaN  0.010101
# ...          ...       ...  ...  ...       ...       ...  ...       ...
# 5226  2024-12-24       NaN  NaN  NaN       NaN  0.004585  NaN  0.007032
# 5227  2024-12-26       NaN  NaN  NaN       NaN  0.002377  NaN  0.010304
# 5228  2024-12-27       NaN  NaN  NaN       NaN -0.008157  NaN -0.011463
# 5229  2024-12-30       NaN  NaN  NaN       NaN -0.009180  NaN -0.012108
# 5230  2024-12-31       NaN  NaN  NaN       NaN  0.003957  NaN  0.012084
#
#           CINF        PG  ...    spread      tail        ts  low_risk  \
# 0    -0.005893 -0.000577  ...  1.227273 -0.009000 -0.010733  0.010070
# 1    -0.008891 -0.005867  ... -0.734694 -0.001816 -0.002406  0.001321
# 2    -0.000236 -0.003290  ...  1.076923 -0.002224  0.009065 -0.002535
# 3     0.004250  0.014755  ...  1.111111  0.011348  0.006375 -0.014668
# 4    -0.008229 -0.005644  ... -1.035088 -0.002204 -0.003840 -0.003715
# ...        ...       ...  ...       ...       ...       ...       ...
# 5226  0.016585  0.004937  ...  0.167912  0.009571  0.032535 -0.003275
# 5227  0.000275  0.007222  ...  0.121800 -0.000379  0.000840 -0.003629
# 5228 -0.008671 -0.003702  ... -0.273056 -0.010186  0.170322  0.007336
# 5229 -0.006317 -0.014393  ...  0.171070 -0.009888 -0.013963  0.003767
# 5230  0.003912  0.003351  ... -0.034398 -0.004064  0.126233  0.004087
#
#       momentum   quality      size     value       ^VIX       spx_vol
# 0    -0.004480  0.002255 -0.005556  0.006790  21.580000  1.678974e-04
# 1     0.001231  0.001307  0.001870  0.001374  20.670000  1.752228e-06
# 2    -0.001107  0.002863 -0.000396 -0.004048  19.809999  5.735980e-06
# 3     0.000857  0.001405  0.004555 -0.010705  17.879999  2.678248e-04
# 4     0.004026 -0.002044  0.002799 -0.000894  17.330000  1.037875e-06
# ...        ...       ...       ...       ...        ...           ...
# 5226  0.001742 -0.000836  0.001441 -0.002167  14.270000  1.219417e-04
# 5227 -0.000382 -0.002163  0.008920 -0.000932  14.730000  1.645328e-07
# 5228 -0.004039  0.000551 -0.003385  0.005571  15.950000  1.222293e-04
# 5229  0.000817 -0.000671  0.002048  0.005083  17.400000  1.145331e-04
# 5230 -0.005310 -0.001124  0.001976  0.006728  17.350000  1.835943e-05
#
# [5231 rows x 2868 columns]
